# %%
import pandas as pd
import numpy as np
import re

# %%
VECTOR_SIZE = 50
INPUT_TOKEN_SIZE = 5
WINDOW_SIZE = 5

# %%
data = pd.read_csv('data/new_locotamerzoa_tweets.csv').text.tolist()

# %%
def filter_rt(string):
    return string.startswith("RT")

def strip_replies(string):
    string = re.sub('\@\w+', '', string)
    string = re.sub('http[s]*\:\S+', '', string)
    return string

def strip_spaces(string):
    return " ".join(string.strip().split())

def filter_data(data):
    data = [el for el in data if not filter_rt(el)]
    data = [strip_replies(el) for el in data]
    data = [strip_spaces(el) for el in data]
    return data

# %%
filter_data(data)
# Out:
# ['🥵🥵🥵',
#  'foda q o pescoço..',
#  '12:39 ainda nao reclamei de nada libertador ...',
#  'cade',
#  'simmm',
#  '🥵🥵🥵🥵',
#  'a sua nao ouvi o desfecho da sua boca!!',
#  'um brinde a minha intuição 🥂',
#  'eh a lei do duende',
#  'vc tem o mesmo nome da gata da minha vó',
#  'todo cabofriense tem cara de que Perdeu Tudo na gas consultoria',
#  'VAI TOMAR NO CUUUUU',
#  'u iu ii. i iuuiii',
#  'bot:prompt 2pac mushroom boy',
#  '😢😢😢😢😢👏🏼👏🏼👏🏼👏🏼👏🏼',
#  'amoo claudinha minha orientadora o design desistiu dela ou ela desistiu do design',
#  'quem eh esse tal de edipo ele quer me comer',
#  'nem no job novo porra!!',
#  'ai joga pro místico e firma com os olhos "espelho quebrado anos de azar"',
#  'coloque-os ali no lugar de pés',
#  'eh um convite a auto reflexão',
#  'dona esse fogao ta quase bom so nao presta 3 boca',
#  'desculpe senhora Nao gosto de pes',
#  'eu a cada 3 meses',
#  'amo vc!!! e seu pombo novo',
#  'eu ami essa frase',
#  'homem eh igual fone de ouvido comprei um airdots da redmi falso e fui ressarcido pelo marketplace da americanas',
#  'ok nenene zuckerberg lelelele rede social nananana estamos trabalhando de graca etc mas muito gostoso ver a infancia dos coleguinha...',
#  'feliz com choco triste sem choco',
#  'traga-me o mindhunter mero mortal',
#  '😳😳',
#  'somos apejas jovens pirados da nossa geracao..',
#  'eu tenho a maior vertigem do mundo potencializei numa oficina de iluminacao q tive q subir uma escada gigante',
#  'tenho maior medo desse Medo',
#  'não aguento mais ouvir Djavan - Maçã do Rosto e agora preciso aprender a dançar forró',
#  'orgulhoso do título Bobão pra Idade',
#  'no final a voz de choro!!!!!',
#  'ta amarrado',
#  'EMOCIONOU',
#  'como um bom barco no mar.. eu vo.. eu vo',
#  'quer mudança segura a criança',
#  'me encontro no pico da glicose com docinho de leite de inhame em plena aldeia velha',
#  'call me mister chicken little em ingles super heroi',
#  'o motorista gente boa de bonezinho ex funcionário da cedae fala muito fala feliz sorri com a fala diz que bolsonaro…',
#  'caraca eu amOOOA lotada como que pode que coisa mais gostosa',
#  'nesse pique que vamo inclusive da próxima o pilantra estara trajado do Manto',
#  'kdkkdkd sim mas nao eh Saber eh Trabalhar com..',
#  'meu deus tudo foi retorcido no buraco negro',
#  'moderadOR TIRA O MOLEQUE DESSE GRUPO AGORAAAAAAAAAA',
#  'caraca isso eh real',
#  'com medo de pedir carona pra casimiro de abreu e acharem que estou comentando um react de hamburguer coreano',
#  'tenho o duro dever de abastecer meus dois amigos com fofocas e novidades sobre minha vida a cada semana mal sabem q…',
#  'iiii',
#  'JESUS',
#  'tudo eh catnip',
#  'tabagato',
#  'abri o guarda roupa do moreno eh só camisa do vascao',
#  'existe cigarro para gatos ?',
#  'por isso tu ta tendo aulinha eh.....',
#  'preso nessa',
#  'criando naRRATIVAS',
#  'oii',
#  'beijando gente que costura alo mamãe e vovó freud intensifies',
#  '😥😥😥sim',
#  '👍🏼bem servido',
#  'papai🤝reinaldo azevedo',
#  'vive luta e avança',
#  'essa eh a famosa Dar uma azeitada',
#  'acordei hoje rindo da interação de voces hj a tarde cresceram duas espinuas enormes no meu rosto va se fuder',
#  'quando o prof de natacao fala Faz mais 4 crawlzinho 🥺🥺🥺',
#  'caraca eu sou completamente lelé da cuca marquei uma viagem na frente fria',
#  'ir no cabeleliro dps de 16 anos??',
#  'virando o padeiro fofoqueiro do bairro tava no portaozinho hoje e o cliente veio falar do casamento dele..',
#  'pronto pro campeonato das loucas empilhadas',
#  'dei meucu pra pagar esta merda de cartao e ele pediu MAIS',
#  'impossível digerir a cpi hoje 😥',
#  '😳😳',
#  'pensei em flertar mas só curti 🙏🏼🙏🏼',
#  'iria de novooi',
#  'hum que delicia o almoço do fogão vomitou e comeu o proprio vomito 🤤🤤',
#  'sou absurdamente CONTRA os meus amigos se relacionarem',
#  'batendo o meu ponto da noite nas redes sociais q criaram um vínculo empregatício comigo sem clt e sem ao menos me a…',
#  'sempre um ser em Sociedade né poroca',
#  'em dois dias meu pc morreu meu ventilador grita comigo toda noite estou vivendo a revolução das maquinas',
#  'eu gosto da cabide mas sou fã mesmo da frestas',
#  'streamer milionário tb vai pra guilhotina na revolução',
#  'põe o vaz na caminha',
#  'nossa parabéns ao karma 🤝👏🏼',
#  'ser amigo de pao de varios tias e tios no insta eh falar qualquer coisa tipo Modelagem De Pao Bundinha e esse povo…',
#  'vou comprar com um amigo agora quer colar? n sei qual eh nao mas eh caro',
#  'GERALDO AZEVEDO SUA MUSICA SABOR COLORIDO EH SOBRE SACANAGEM?',
#  'vivendo a minha maioridade: comprando peças para skate de dedo',
#  'passando o café',
#  'vem vamos nadar na praia',
#  'amiga estamos preparando o bolchefitness',
#  'quer passar a terceira idade comigo catilanga',
#  'eh um absurdo eu não aguento mais',
#  '89 90 91 92',
#  'futuro: skates que voam robos escravos nosso futuro: tiktik da moça robo do google falando',
#  'nao da pra fazer carinho em couve..',
#  'to Abujamra das ideias',
#  'nao tenho nada com isso me tirem daqui..',
#  'respira..',
#  'CUSPI O TABACO',
#  'quer namorar comigo?',
#  '😳😳',
#  'até papa peca!!',
#  '😳😳',
#  'infelizmente solteiro para sempre !',
#  'doi muitooo',
#  'meu idolo me reblogou🥵😥😇🥺',
#  'abri aqui e acho q fui cancelado',
#  'o cara aqui na nataçao q o job dele eh bota as Maiores dos remix de oasis pra tocar',
#  'eh muito romantico ne a parada eh que nao eh bom Querer Sentir mas vc cai nisso sem querer né aí ao menos curte o banzo',
#  'tem tempo e parte eh drama mas eh bom sentir um toquinho de emoção...',
#  'infelizmente vivendo e sentindo o álbum Certa Manha Acordei De Sonhos Intranquilos',
#  'o homem que perdeu o cabelo é capaz de perder qualquer coisa',
#  'só penso nela a natação..',
#  'sim 😳',
#  'eu gosto eh da organização thi..',
#  'no inconsciente alheio sou o famoso Empata Suruba',
#  '',
#  'jelly time !!',
#  'o papao nao gosts de gengibre..',
#  'pita q pariu eu ia dormir agora',
#  'hidratando o pezinho antes de dormir pro papao nao pegar',
#  '',
#  'acabei de rir muito e meus dedos só conseguiram digitar o kkkkkkk em que canto da internet q perdi a minha web alma..',
#  'kkkjkkkkjjjjkkkkk',
#  'o freixo ganhou todos os nerdola liberal numa ida rapidinha no flow',
#  'sempre q vou ao la kanna os caras sao tao fofos q acabo comprando qualquer coisa',
#  'toma no cu o tio joao ta 8 conto',
#  'benza deus',
#  'obrigado anonimo reze por mim..',
#  'ai toda hora da um problema novo e parece q eh coisa da mobo... mas ele nao ligar periferico nem nada seria ram tb?',
#  'sim!! tenho tido problema c memorias e ja limpei (as vezes uma funfa, dps outra, ultimamente qlqr cois…',
#  'meu pc liga mas nao da video/periferico n liga ai falaram pra fazer isso deixar uns 10min',
#  'show!! preciso passar ele da posição normal pra posição c_cmos',
#  'nossa que tristeza 👏🏼👏🏼',
#  'só tu lá',
#  'mande aquela mensagem safada q vc sempre quis mandar aproveita que nao da pra ver 🤮🤮🤮',
#  'onde ficam os pinos C_CMOS da placa mãe e oq eh um JUMPER',
#  'preciso da ajuda de um Nerd',
#  'ikkkkkkkk r*naldo l*mos de sunguinha na tv pedindo pra reeditarem o take',
#  'sempre q vejo ronaldo lemos na tv arrepio de trauma do canal futura..',
#  'deu ate 🥵🥵',
#  '🥺🥺🥺🥺🥺',
#  'poxa amigo ia matar a paõ...',
#  'eu so eu e boi nao lambe se morde eu corto a lingua',
#  'e eu la quero saber o que aconteceu de fato quero ser abastecido com 7 teorias da conspiração diferentes 👍🏼👍🏼',
#  'um fofo',
#  'nao dou mole pra gente lowprofile',
#  'que papinho de nerd hein cade a bebida',
#  'tu voltou pro twitter tipo um soldado se apegando a ultima trincheira disponível na guerra da internet',
#  '',
#  'ip e ping ip e ping abriram o speedtest',
#  'A ACAD NAO CAIU NAO HEIN HOJE EH DIA DE BIRLRLRLRL',
#  'o correios caiu tambem ninguem tem mais cep nao ouviu a ultima',
#  '👏🏼👏🏼👏🏼👏🏼👏🏼👏🏼👏🏼👏🏼👏🏼👏🏼👏🏼👏🏼',
#  'irmã nao sou nira vc esta pirando no bug do milenioooo',
#  '🥵🥵ja abri pra limpar notificação do insta umas 9x quero me mata',
#  'cai tudo menos a tua bermuda tactel da cyclone 😉🤤',
#  '😳😳😳😳😳 não trabalho com pães senhora desculpe...',
#  '😥',
#  'botei o meu fermento num creme de castanha e simplesmente esta CRESCENDO eu posso fermentar TUDO venha aqui que eu…',
#  'vc eh meu noco melbor amigo...',
#  'nao vai rolar pq teu pau deixou a desejar..',
#  'meis amigos ja nao me aguentam mais 😢',
#  'era alguma música que falava em pequenas letras que o bob era gay agora não lembro quem',
#  'catila toda força pra mulher intensa..',
#  'impressao sua amigo!!',
#  '👀👀',
#  'sim numa dessas já encontrei o amor',
#  '',
#  'calma amigo mark só esbarrou nos fio',
#  'ACABOU O SOL EH O FIM',
#  'me falem a altura se conseguir ir eu vo!!',
#  'cade o fluxo de migração telemática para o telegram',
#  'tatua na praia agora tudo tem q ser feito na praia!!!',
#  'pedra bial caiçara obrigado pelo lembrete 🤝',
#  'fujam dos respectivos trabalhoa e vamos a praia!!! f…',
#  'nossa bateu essa ideia agora adorei a confirmação',
#  'festa no twitter AGORA todos online quem trazer as birita',
#  'TWITTER SEGUE IMBATÍVEL',
#  'pocinhas pular cerca (lisa) vou sim anjo quando parar os trabalhos..',
#  'isoooooooooo ja tenho 3 coisas',
#  'um dia andorinhas outro dia 7quedas',
#  'meter a mao em de vaca!!',
#  'brincar de massinha',
#  'estou falando com a embaixadora de S.J.',
#  'fumar maconha na trilha da 7 quedas',
#  'gente oq nao posso deixar de fazer em Aldeia Velha????',
#  'que saudade que saudade',
#  'atropelado por uma loucomotiva',
#  'postei uma besteira me curtiu quem?? um machamp e um kirby',
#  'gostando seu putico!!',
#  'TUDO DELES',
#  'foda reginho.,,',
#  'obrigado anonimo',
#  'porra desculpa nao mando mais',
#  'mei irmao comeu meu acaraje e eu wuero mata-lo😡😡😡',
#  'eh um abuso ANUNCIAR a fofoca sem intenção de EXPLANAR',
#  '😡😡😡😡😡😡',
#  'eu a chamo de tesão encroado',
#  'aqui é pura emoção',
#  'vo te aplica um café pequeno',
#  'essa galera toda eh simplesmente um moleque do forum uol jogos',
#  'a maior rivalidade do brasil',
#  'kkekekekkee os queimadores de rosca 😜😜😜',
#  'roupasso do domingo',
#  'schopenrauuuuuuuuuuuuuuuuuuuuuu',
#  'simm essa OBRA eh uma crítica ele se ridiculariza cria um espantalho pra criticar uma classe!!',
#  'ta beijando gente q gosta de pdeira ne safada!!',
#  'auuuuuuuuuii',
#  'por fabor computador vc poderia ligar marquei rpg',
#  'esses são terríveis',
#  'vale tudo no jogo da seducao !!',
#  'manda dois',
#  'ja parei meu limite eh enfia o dedao',
#  'valeu di',
#  '',
#  '',
#  '',
#  'me contaaaaaaaa',
#  'se for gostosinho as vezes ate rola..',
#  'acha um saco de papel bota uma banana e ele deixa namorar..',
#  'vc eh imparavel!!',
#  'pe pra fora = pedir pra ser puxado pelo craminhao',
#  'espero q continue assim tomo uma cerveja e me acabo..',
#  'um belho trabalho de Semiótica',
#  'hoje simplssmenyr perdi o conyrole ds minha. vida',
#  'quando termina e quer alfinetar',
#  'virei o cabofriense de sunga boné e bike',
#  'hmmm',
#  'se vendessem krokodil em vez de alcool falariam Que Absurda O Uso Da Droga Que Acaba Com Vidas',
#  'viva!!!',
#  'INTERESTELLAR É UMA CRENÇA NEOMALTHUSIANA',
#  'pra fechar esse dia so falta a icarly universitaria',
#  '😳😳😳😳😳😳😳😳😳😳😳😳',
#  'gostou do monstrasso',
#  'que isso jesus',
#  'que continuar streamando tenho mais oq fazer filhote',
#  'amo pao meu deus que mundo lindo',
#  'esse cara eh terrivel!!',
#  'esse cara eh terrivel!!',
#  'ainda bem que na revolução a primeira fila de guilhotina vai ser gente tipo otavio fakhoury',
#  'REITERANDO',
#  'vamo um valorant',
#  '👍🏽👍🏽👍🏽👍🏽👏🏼👏🏼👏🏼👏🏼👏🏼',
#  'por favor quero uma unidade de fim de semana',
#  'nao vai se repetir',
#  'intenso ne',
#  'meu google keep atualmente eh so anotacao de trabalho vida devolva a minga fantasia',
#  'o doido de voltar a morar com a familia em cabofri eh que eu tenho que odiar os outros times agora !! toma NO CU MENGOO',
#  'tweet de amor dedicado a pessoa q criou o incensinho nag champa',
#  'comite de pragas urbanas',
#  'te acompanha irmao..',
#  's...s..',
#  'vaMOS',
#  'ta errado!!',
#  '',
#  'guerreira!!!',
#  'thiago eh tao preguiçoso na busca da ENDORFINA que mandou são pedro faze chuvê',
#  'CASA LOTADAAA',
#  'cpi no maior estilo decada de 90',
#  'humm',
#  'muito dificil começar o dia com esse video e esse discurso',
#  'sem tempo pra normalizar a romantização hoje',
#  'que jpg pesado',
#  '',
#  'ai ai ui ui nesse pique aqui',
#  'eu pego duas vc duas fecho',
#  'porra o algoritmo cismou que eu quero 4 shorts 100 reais caralho porra de 4 shorts',
#  'essa e pra quem e preconceituoso e acha que branco nao pode tocar samba',
#  'bigode é a franja da mulher??',
#  'acho q nao to bem ha mt..',
#  '',
#  'OCNJJFFJXMCNFJSHJFFDDUSHD',
#  'tao louco q empurraria um carro na lapa?',
#  'q da mole pra aluna de 15',
#  'saindo voado da natação pra compensar a abertura do meu pulmão fumando o famoso pretinho uva',
#  'nunca vi assim!!',
#  'imaginando o tal ANCAPISTÃO cheio de Prevent Senior da vida cuidando da saúde da população',
#  'vendendo pao pra burguesia cabofriense terça feira: um alemão veio comprar pão pois a Empregada dele não sabe fazer…',
#  'vc sempre esteve a frente da geração gio..',
#  'sim!!',
#  'SENADOR VOCÊ COMPROU ESSE DIPLOMA?? MUITO BURROOOOOO',
#  'o lobby da paõ é tão forte que assusta até os psicólogos mais Jungianos',
#  'reiterando o otavio fakhoury NAO eh o meu pai!!',
#  'alo nova geração eh feio dividir o cabelinho??',
#  'esse ja deu briga aqui em casa..',
#  'fecha o olho faz uma planta baixa do quarto na cabeça que o item vai piscar na sua mente e vai ate la',
#  'fico bobo de como preacher eh horripilantemente bom',
#  'imaginamos vc presa no legpress..',
#  'mas realmente faz mais sentido ir pertinho..',
#  'vai de bike q ja fez o primeiro exercicio!!',
#  'po foi o mais baratinho q achei eh perto do greenfruit... eh meio foda se la tb',
#  'bioforma!!',
#  'hoje bati de frente com minha maior inimiga a "acad"',
#  'mensagens antes do apocalipse',
#  'ando devagarinho',
#  'mas a foca simplesmente brotou e fez cara de tipo to tranquila aqui',
#  'qual FOI irmao agiliza aeeee',
#  'LAURA QUR VIDFFKFKDK MEU DEUS',
#  'nunca pensei que palavras joelho e casca de banana estariam compondo a mesma frase',
#  'assisti esse je suis karl e eh tao mal diagramado que parece uma propaganda fascista',
#  'nunca mudou',
#  'só um docin de cosme e dami pra segundar legal',
#  'hoje eu vou gerar o LEGPRESS',
#  'sonhei com meu antigo trabalho e acordei aliviado pronto pra começar a semana muito feliz obrigado deus',
#  'o vizinho esta Paracundê Paracundê Paracundê Paracundê Paracundê Paracundê ha muito tempo que musica infernal eh essa',
#  'esse foi pra mim ne',
#  'a palavra Atabaque muito gostosa de falar parabens palavra Atabaque',
#  'a nao!!!',
#  'faz um video reagindo a reação dele',
#  'SIM',
#  'nao aguento mais achar q eu devo assistir o casimiro reagir a TUDO',
#  'ui essa rolou hoje..',
#  'pedro bial ganha dinheiro sempre que vc usa protetor solar',
#  'essa ai ate anjo vira Diabo',
#  'pra descobrir quem foi o assassino nas películas suzaninha von é simples: quem fumou a primeira maconha foi o manda…',
#  'kkk nem chama pra f1 ;)',
#  'pai!! afasta de mim vc fazendo almoco 10 da manhã',
#  'eitaa',
#  'o Picanheiro é o topo da hierarquia da churrascaria',
#  'infelizmente deste vinho eu bebi',
#  'acometido por 3h de carla cruz',
#  'OLHA PRO CEU MEU AMOR',
#  'envolve um salineira lotado',
#  'comer uma fatia de torta salgada',
#  'bater de frente com o vento cabofriense',
#  'torcer pro vasco',
#  'jogar no bicho',
#  'muito triste ter saído daí sem ter encontrado mt vcs pq nao vem todo mundo morar em cabo frio??',
#  '😳😍😢🤝',
#  'gabtiel que ocasião nos conhecemos estava tentando lembrar',
#  'boa alimentacao loui!!',
#  'sabado dia oficial de combar um Uaipastel Uaiçai',
#  'tem q ter maturidade tb de nao esperar que seja a melhor coisa do mundo..',
#  'sdd quando a complexidade da vida era grava dvd no nero burning rom',
#  'calma anjo vai chegar... temos q aproveitar os misterios....',
#  '😳😳😳😳😳😳😳tentei ser hater mas nao consegui',
#  'SIM',
#  'nao ganhou 😔',
#  'ui ui lindo moço veio na caixa? 😹😹',
#  'a tremedera de madrugada',
#  'pensar que cada amorzinho custa 4 reais e 3 cents',
#  'mamae sonhou com numero me tirou 30 conto e foi la joga no bicho',
#  '3k o aluguel em sp',
#  'se todo livro tivesse desenhozinho e balão de fala eu tirava de letra..',
#  'a harpia que com o nome de gavião real mas que é uma águia',
#  '😢',
#  'esse eh quem',
#  'proteina de piroca',
#  'ta chegando ai vai pro portao...',
#  'varias letra ne',
#  'amiga que palavra louca ate googlei..',
#  'coleciono',
#  'jESUS',
#  'em cruzeiros!!',
#  'sim acompanhar os coroa no circuito de ARTES uma moça de salto alto com um violijo andando na pedran',
#  'quanto sera uma pipoquinha em buzios',
#  'fulano (tinder)',
#  'ta mas me responde uma coisinha',
#  '😜😜😜',
#  'VAI MENGAUMM',
#  '🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣🤣',
#  'cuidado leo..',
#  'o que significa??????',
#  'hoje e sexta feeeeraa',
#  'nao consigo mais perdi o controle ds minha',
#  'caraca meu irmao esta teclando muita poesia por segundo',
#  'eu mostrei o cu um dia e fui exposto',
#  'ja perdi de novo..',
#  'decidi minha vida em 27segundos',
#  'so quem salva e cristo ne irmã',
#  'nao',
#  'nao nao o da monica tem uns pozinho branco dentro q fica mais gostoso!! uma crocancia! vitaminas variadas... o anjinho no rótulo',
#  'o turma da bonica só',
#  'pizza vegana com borda de bacon',
#  'ola uriguaio quer q eu bote o q no teu forno ??',
#  'vamo',
#  'esse eu conheço..',
#  'suco de picolr',
#  'mas tem 6 picoles',
#  'limao',
#  'thiago abre a porta o picole está derretendo',
#  '❤️maria❤️das❤️mercedes❤️',
#  'sacole de bosta???',
#  'e hoje no incrivel mundo do tamer padeiro em cabo frio surgiu um uruguaio me convidando para assar pães no forno a…',
#  '(meu segredo eh q eu sou um rapaz esforçado)',
#  'eu nao tenho seu email ninguem ama somente por email',
#  'SEGURAAAAAAA O SDNADOOO',
#  'PORRADA TORANDOOOOOO',
#  'moral definição ou significado',
#  'mae to no print!! força amiga..',
#  'O BICHO VIVOOOO',
#  'que saudade de juntar a familia pra matar sacolé de fruta..',
#  'todos q fui eram lindos',
#  'o mundo acabando e vc vem me falar de reveillon..',
#  'ESSE',
#  'oh que belo video do atila hum tema interessante um minuto depois ja nao entendo mais nada uau que legal este quadr…',
#  'eh grana ne a netflix quer seu tempo!!!!! acho q começou como spinoff mas brilharam no roteiro',
#  'me da um sinal!!!!!!!!!! 😡',
#  'ue mas as ultimas temps sao as melhores',
#  'eh MUITO bom',
#  'papai cheirou 50 eps de better call saul em 9 dias',
#  'eu e vc somos uno nao tres igual adidas nem par que nem mizuno',
#  'relaxa meu sobrinho tem corel instalado vou pedir pra ele faze',
#  'preso no limbo do goonygoogles reagindo a rapper br',
#  'Acabou de publicar uma foto em PAÕ',
#  'mais um dia pensando nele..(meu sodexo)',
#  'é a maior que nós temis!!',
#  'novo hobby de mamae eh ver live de vulcão',
#  'hum nao sei ela tem 1,70?',
#  'solta o som dj raul',
#  'comprovado que luciano hang venderia ate a propria mãe',
#  'um veganismo q deixe comer apenas um animal o mosquito',
#  'não faça isso senador...',
#  'ACABE COM ESSA DROGA DE UMA VEZ...',
#  'esse ai ja foi surrupiado faz tempo 🤣🤣🤣',
#  'cometendo o desleixo de dormir nu porém atento aos coiotes',
#  'parabens desenvolvedores do gartic phone 🤝👏🏼💪🏼🙏🏼',
#  'p mim eh a sua',
#  'palhaco pagliati perdidasso',
#  'sim',
#  'ok',
#  'eu vivo pra isso queria ser ele..',
#  'estou no bico do corvo',
#  'vou ensinar ela a praticar reiki',
#  'AHHHHHHHHH JCJJXKXDKDJDJDDK',
#  'nao acredito q te criei te alimentei paguei sua escola para vc sair com instrutor de reiki',
#  'TA LINDO BOTAAA',
#  'junte-se ao bonde loco&lt;nome&gt;zoa com avatar de filtro q deixa todo mundo gostoso',
#  'vc vai longe!!',
#  'por esse preço não te levou no Uaiçaí ou seja: bofe escroto',
#  '😔😔😔😔',
#  'relaxa... eu entendo...',
#  'ainda vai morrer por causa de mulher hein miga..',
#  'eu sou o que',
#  'foda q o pescoço dela eh lindo..',
#  'ALERTA SUDOESTE',
#  'bolsonaro so matando msm n te como',
#  '😡😡😡😡😡😡',
#  'pra mim essa flor 😳 ?',
#  'vc acompanha...😳😳',
#  'esse tb eh um classico!!',
#  'isso',
#  'na porta do sagrado só dava ele..',
#  'obrigado',
#  'no momento utilizando o filtro mais bonito do mundo',
#  'esses dias vi um classico cabofriense o Cazuza com um bolo de panfleto na mão',
#  'por isso na primeira vez dói',
#  'amanha eh dia de testar se thaigo e juqua conseguem acordar as 6 da matina..',
#  'o famoso pau pobre',
#  'ja nao sei mais se ontem foi ontem ou se foi hoje',
#  'nunca vi uma moça feia na vida!!',
#  'AUIOHSFASFAOSÇFMAFS',
#  'sinta tudo inclusive tua baixa renda',
#  '1milhao de reais para erguer o BUSTO!!',
#  '💪🏼💪🏼💪🏼🚀🚀🚀',
#  'ja fumou um "baseado" hoje',
#  'oi?? nao entendi pq esta rindo pra mim!! achei simpatico',
#  'buildando a barriguinha da pandemia marca registrada',
#  '😳',
#  'LINDOOOOOOOOOOO',
#  'xaralho que coisa tenebrosa e essa letra',
#  'sonhei que tinha um boi de estimação no quintal',
#  'dormindo pelado com uma faca ao lado nunca se sabe quando a matilha de lobos te atacará de manhã cedo',
#  'adoro essa',
#  'doida pra comer a professora',
#  'queria ser amigo de alguem e esse alguem tem uns 3 amigo merda no ciclo',
#  'bolsonaro vai SE fUDER deagRacado',
#  'boa',
#  'sim foi pensamento intrusivo',
#  'mas veja bem cade a sororidade muito machismo aconteceu com ela na cpi 😡😡',
#  'hum que faca bem afiada chop chop chop que loucura seria se ela Caisse No Chao Cravasse Bem No Vaso Sanguíneo Do Me…',
#  'me pergunto se ela se pergunta',
#  "naquela mesa ta faltando ele.. a saudade d'ele.. ta doendo em mim",
#  'hum mosquitinho venha aqui venha',
#  'tentei nao consegui',
#  'eh que eu fico com o do jacare na cabeça',
#  'está andando pela sala',
#  'NESTA PLACENTA ESCROTA',
#  'sera q o bebe esta confortavel',
#  'vau tomar j ofuxudixixixi cuuuuuuuuuuxaelagooooo jjkdjdjdj',
#  'uau que rostinho bonito ele e todo seu ?',
#  'pessoal eh emocionado ne',
#  'cheiro de cu de enxofre',
#  'se VENDEU',
#  'vc compraria este bonego agui',
#  'posso parecer inteligente mas foi minha amiga medvet q respondeu isso tudo!!',
#  'se vai apresentar algo diferente do normal... a mucosa tem que ter uma cor de saúde, rosinha..',
#  'então, é muito subjetivo né pode ser tudo como pode ser nada. daí eu ficaria observando o comportamento de…',
#  'depositou o conteúdo em que lugar? será que o gato lambeu? mas letárgico ao ponto de não comer e nem beber?',
#  'qual marca do vermífugo',
#  'caraca falou que lingua',
#  'hora do remedinho',
#  'mamae um dia chegou com meias descartáveis que dentro tinha hidratante ai vc botava e fazia massagem e dorm…',
#  'hum imagina hidratar os peszinhos com um hidratantezinho de gengibre hum que delicia de pezinho Opa esqueci a luz l…',
#  'sim sinto isso sempre qd paro',
#  'Primeiramente, a família de Gustavo Borges veio para Palmas logo início da criação da cidade, em 1990, po…',
#  'eh de investimento em criptomeodas',
#  '',
#  'foi a macinha ou meu relaxante muscular',
#  'porra de criança e essa q sabe oq eh um Petroleo',
#  'porra embuchou se vira ne quer dinheiro dos outro',
#  'muito caro desisti.',
#  'fui orçar umas aulas de nataçao a mule me conta Utilizamos a metodologia GustavoBorges.. eu hein vo la querer saber…',
#  'mulheres sao assim??',
#  'vem viado gravido',
#  '',
#  'sabe.. eh de uma praticidade..',
#  'alguem consegue fazer o lockdown dos insetos',
#  'eu quero me embriagar no nectar da sua existencia',
#  'AUHUIAOAHAFSAS',
#  'amo as reaçoes seguidas dos trocadilhos',
#  'kkkkkkkkk',
#  'entre mulheres eletricas sereias e um branquelo',
#  'isso aqui foi inspirado numa primeira sexta na escola de belas artes',
#  'a globo fabrica seus próprios apresentadores dentro do próprio programa famoso de reality show é tipo um time grand…',
#  'na arte vale tudo mas nao vale qualquer coisa',
#  'munido hoje de 6 travesseiros',
#  'créditos: astronomo amador',
#  'caramba pesado...',
#  'doidasso de remédias..',
#  'ta pra nascer alguem mais desgra;ado que esse sujeito',
#  'imagino o cara sentadao todo dia olhando jupiter parado 10 anos nessa 24 por dia nunca parou de olhar jupiter ai el…',
#  'eh oficial temos que voltar a jogar beyblade alo cabo frio',
#  'porra vou ter que fazer uma intervençao',
#  'porra dia todo no crossfit kd os 48 de braço',
#  'os olhos pretos da simone tebet 😳',
#  'soraya thronicke o que seria uma direita séria?',
#  'soraya tchrneoeneiccckle quanta bosta irmã!!',
#  '🔥🔥🔥🔥chama no zap amor ??',
#  'nossa imagina se chamam a famosa ana cristina valle #CPIdaCovid',
#  'pusserinha',
#  'arranjar uma coroa gostosa cabofriense pra dar conta do meu plano de saude',
#  '🥺',
#  'dps do meu pai me passar problema de joelho coluna calvicie mamae me passar problemas intestinais só vou reproduzir…',
#  'isso ej uma dança??',
#  'hummmmmm',
#  'boa',
#  'opa!!!',
#  'eu sou camisa 7 parça',
#  'este anjo ajudo minha dor na lomba!!!',
#  'tu',
#  'torta sogada',
#  'amiga quando menos espera rola isso..',
#  'imagina vc ta tranquilo ai surge a Gangue do Poliamor',
#  'nao sei eu só reproduzo..',
#  'tava vendo!! fala muito em ingles ele mega nerd.. amei a cuia com cantinho quando a bb toma porrada.…',
#  'METER O DYNAMITE BATTLE',
#  'cara sem meme meu maior sonho era voltar (hj q posso comprar vários) achei esses dias uma peça aqui f…',
#  'o brilho = tamanho da terra',
#  'caraca esta tudo Vuashhhhhhh',
#  'falou em terceira pessoa eh ban',
#  'exatamente essa eh uma q me salvando (mas nao usava travesseiro otima ideia)',
#  'o sapicao do met gala',
#  'descobri 37 posicoes que nao consigo dormir sem sentir dor e talvez duas que talvez sinta algo menor',
#  'ihihihhi esse ai ele perdeu',
#  'pega o papel pegou??',
#  'falo de beijo na voca a galera se assanha..',
#  'eh o beijo triplo',
#  'sonhos akira kurosawa',
#  'putz meroka',
#  'nao sou eu..',
#  'como é eh legal',
#  'vai buscar quem mora longe sonho meu',
#  'anna amei o uso do filtro !',
#  'ja beijaram alguem com a tal Lingua Bifurcada ?',
#  'esperando o castor aqui no excel',
#  'tao sufocado de tanta coisa pra assistir que vou só ver as thumbnails',
#  'ta chegando a frente fria rlx',
#  'por que VOCE nao se vestiu desse jeito hein?',
#  'nao sei foi algum resquício da covid com agum mal jeito vou ver amanhã no medico nao consigo nem abaixar...',
#  'show!! tava pensando em fazer natação tb.... intercalar...',
#  'onde foi? porra toda semana que vou começar deus nao me deixa',
#  'bento mecânica de fluidos',
#  'claramente a fusao dos dois Heitores',
#  'cada hora uma gente nova',
#  'eu quero nascer cigarra',
#  'putzz',
#  'pensar aki..',
#  'pq ta cheio de rico de roupinha na minha timeline',
#  'microajustes',
#  'trabalhei com um horrivel q adorava mandar essa',
#  "eh tudo d'eles",
#  'o utero deu uma pontada ne..',
#  'obvio que a jblinha foi o maior investimento',
#  'o cheddar ali foda se',
#  'muito dificil guardar segredo nao conseguiria... leva um presente..',
#  'ai namoral me enterra',
#  'conta',
#  'queima uma folha de louro',
#  'o prazer da rinite alérgica',
#  'ate tu henri',
#  'lkkkkkkkk mlk que issi sensacional',
#  'descobri esse dia que o fogo na reacoa do insta tem a traducao tb de "Chama" pra chamar no zap',
#  'jogar d&amp;d faz meu peito explodir de amor',
#  'tomando uma sopinha',
#  'lançar essa um dia quem sabe',
#  'vamos brincar cada 1 like aqui = nao vou comentar nada a respeito',
#  'tudo bem',
#  '😳😳😳que isso ..',
#  'e ele com wings',
#  'ep2',
#  'o calvo em mim aperta a mao do calvo em nós..',
#  'o cheiro de monster e criptomoeda é terrivel',
#  'lingelinda',
#  'vou..',
#  '23 quatro cinco meia srte oito!! tana hora de molha o biscoito (o piraque maizena nao pois tem soro deleite )',
#  'estou pulando em suas notificacoes pois ej minha forma de mostrar q estou saudoso..',
#  'eu sou comunista fako com todos todas e amo os animaiszinhos ... nao uso a roupa "afogue as feias@"',
#  'sorvete',
#  'odria homens',
#  '👏🏽👏🏽',
#  'mudo tudo cada 2 semanas parece q eh vida nova',
#  'sera que menina estudiosa usa calcinha de renda?',
#  'lembra daquele liberal que voce encruzilhou',
#  'sum',
#  'esse ouve black alien e speed',
#  'gostou do torto ??',
#  'um sistema que eu nao precise gerar lucro pra sobreviver a qual fique a semana toda assando pão pra distribuir na c…',
#  'eu amei o comprido!!',
#  'brabo',
#  'rustico',
#  'tem que ter muita pouca vergonha pra chamar bolsonaro de Traidor mostrando que um dia você teve a coragem política…',
#  'ainda bem q nessa aqui nois ja nao cai mais',
#  'minha lombar quer se separar de mim e viver uma vida independente',
#  'fez tudo e virou do avesso',
#  'prestes a perder tudo no Carteado',
#  'imagina meia noite..',
#  'um getulista dá uma rosa para a leitora de adam smith... os olhares se batem... existe amor nesses tempos?',
#  'isso aqui eh muito sitcom',
#  'NOSSA agora bugou pq eu lembro que cantava errado quando era pequeno... ai um dia meuis irmaos riram de…',
#  'dando toda minha grana pro proctologista 🥺',
#  'eu sempre cantava "sangrar"',
#  'vai tomar no cu o outro relato dos pés..',
#  'UJDJDHDHDHDUS',
#  'nossa Niterói eh terrível ne!! no meu caso fui ver um show horrivel de algum banda podre que nem a pessoa…',
#  'descobri que pra ser feliz vou ter que calcular temperatura de água e farinha..',
#  'sim! mas quem vai ter o bigode?',
#  'fui beija na boca em niteroi nao beijei e terminou a noite ela doidarassa tentando mijar exatamente dentro de um ga…',
#  'o verdadeiro trabalho do padeiro é administrar tempo e temperatura..',
#  'perfeito eh vc!!',
#  'sempre q esse video aparece eu vejo todooo',
#  'amo a do pezinho preto',
#  'meu maior receio',
#  '🤝',
#  'obvio',
#  'me acha biito 🥺😳?',
#  'fui chamado de feio ao menos nao de calvo',
#  'CARAIO ZE TROVAO AQUI JESUS DO CEU',
#  'oi meu nome e podrao',
#  'POR FAVOR VOCE QUE EDITA O SOM DO CARALHO DO PROGRAMA DO REINALDO AZEVEDO AJEITA O VOLUME DESSE CARA ELE GRITA MUIT…',
#  '🥵',
#  'gostosa !',
#  'pós covid ta pior q covid',
#  'gostosa',
#  'muita sabedoria nos próximos caminhos anjo deixou um pouquinho de vc em cada nerd xexelento...',
#  'esse mole eu ja dei..',
#  'comi um pacotinho de teens q vai me deixar ligado pelo resto do mes',
#  'eu nao fiz nenhuma declaração',
#  'oficialmente um Tullecer',
#  '😎😎😎😎😎😎😎',
#  '?',
#  'RICARDO',
#  'caraca sei nem mais se de fato estou vivendo a realidade',
#  'sonho',
#  'vi tb!!',
#  'quem vai me mamar?',
#  'caramba!!',
#  'volta p mim',
#  'segunda noite enboibando o cadeçote',
#  'poxa achei q estava 😢😢😢😢',
#  'queria ser seu padeiro particular testar meus Zaatar com vc',
#  'garimpei no app ****** e fui surpreendido 😳',
#  'tava fora do brasil irmao',
#  '🥵🥵',
#  'tira bolsonaro e bota o casimiro',
#  'au au au 🥺🥺',
#  '🥺🥺🥺🥺🥺🥺🥺🥺🥺🥺🥺🥺🥺🥺🥺🥺🥺🥺🥺',
#  'opa!!',
#  'que isso irmao na minha padaria todos sao bem atendidos...',
#  'a ultima que falei fui ignorado',
#  'vendeu a alma',
#  'simm logo ali',
#  'choque de poderes',
#  'quando rola o tabaquinho das 7 eh que o dia promete ser estressante e horripilante',
#  'nao godtou?',
#  '',
#  'nem tem tantw gente assim no mundo',
#  'to assim hj o dia todo planejando',
#  'amigo nao sei se tu sabe mas eu sou do capitão',
#  'vai sair sem perna agora',
#  'xandao..os instintos mais primitivos..',
#  'isso eh um album',
#  'esse pato eu nao pago',
#  'a democracia eh um jogo q estamos perdendo só de acreditar nas regras do mesmo',
#  'in fux we trust',
#  'queria q meus amigos fizessem intervenção sempre que dou mole pra alguem q nao mora na minha cidade',
#  'que isso eh fetiche?',
#  'caraio gladison',
#  'que isso como assim',
#  'trazer uma felicidade pro povo',
#  'nunca mais falar de a*** aqui pois n aguento mais notificação',
#  'eita estava pelas bandas',
#  'kd',
#  'sempre confie nas histéricas',
#  'kkkk eu achei q nao ia dar em nada o negocio mas o assunto eh quente',
#  'é muito doido simplesmente pensar que sempre criamos nossos monstros (o dia de amanhã não seria nada sem o pânico d…',
#  'viu oq vc fez nao paro de receber notificacao...',
#  'botei o pe pra fora de casa e ouvi um grande hino nacional sendo tocado sei la onde',
#  'amanha eh dia de botar esse twitter pra funcionar (xingar bolsonaros)',
#  'os cara sao tao burro q tao gastando a Invasão ao Capitólio (1 unidade) um ano antes da eleição',
#  'fiquei até boquiaberto',
#  'taca lhe xota',
#  'mesmo em 2021 consigo ler na sua voz...',
#  'ansioso para dormir acordar e ficar o dia todo com raiva de três cores 🤢🌝🥶',
#  'eh o cabofolia da terceira idade',
#  '😢😢',
#  'oi',
#  'eu nao nasci pelado nasci trajando uma blusa cinza mescla e shortinho cinza mescla',
#  'galerw gosta de fofokinha..',
#  'que os orixás te guiem irmã!!',
#  'faz um video pro teu boy com o seu pe na privada e produto de li mpeza',
#  'JASOPFHAFSU botou a casa e o pedro junto',
#  'aqueles tasty demais',
#  'true toxico',
#  '🥺🥺🥺🥺🥺🥺🥺🥺🥺',
#  'até hj esse e meu nome!!',
#  'mas agora vc pode desfrutar da sua recompensa: ser alguem legal em 2021',
#  'bicho se vc tivesse a sacada de entrar no youtube anos atras hj seria O BICHO',
#  'com o novo integrante Julhous',
#  'a historia eh bem doida cheia de altos e baixos e varias cosias feias q essa galerinha ai fez to pra…',
#  'junto com a recem namoradinha e mandou geral pra fora pegou grana pegou conta tomou conta de tudo e fomos saindo aos poucos',
#  'poxa longa historia mas basicamente o alan só ganhou visibilidade pq trabalhava com mais 4 pessoas(i…',
#  'fiquei bobo tb 😳😳',
#  '🙏',
#  'eh o famoso efeito cadela',
#  'eu sou um perigo pra eles... sei muito..',
#  '',
#  'gosto de meninas pique evangelica (saia jeans ate a joelha e cabelo preso)',
#  'rUSTICA',
#  'que dia do sexo o que irmao quem faz isso hoje em dia',
#  'bicho q doidieira',
#  'não te seguia anjo agora vou interagir...',
#  'desculpa',
#  'nerds',
#  'hoje eh cafe puro na veia sem nada',
#  'vc sempre cafe da manhazada ne',
#  '🤢🤢',
#  'bom dia tomaram o cafe ja',
#  'mais uma noite comendo pizzas de LoNgA FeRmEnTaCaO na cidade e ficando cheio no segundo pedaço 🤡',
#  'no seu leito de morte ele mandou chamar um pastor',
#  'vc tem ideia como darwin morreu',
#  'muito doido esse lance de Doente por Stress ai vc fica PUTO pq ta doente entao eh um ciclo sem fim',
#  'para cara tira esse sentimento q te corrói',
#  'absurdo',
#  'Kid Abelha foi uma banda de rock brasileira que fez sucesso no país em Show Da Paula Toller',
#  '😢',
#  'tem algo mais bolsonarista do que asa delta com motor',
#  'ouvi o papo de um coroa aqui do lado e decidi minha vida: mermao chega domingo vou ali na pedra fumo um pouquinho f…',
#  'xbbxbxbxbdhjxnxnsjsjdjxnxndhfh',
#  '',
#  '',
#  'caraca igualzinha a menina q fui apaixonado platonicamente por um ano...',
#  'fiz um toktok com linguagem de toktok pra ver se o negócio da view mesmo #TikTok',
#  '',
#  'to ligado no "food"',
#  'putz horny m',
#  'quem foi ultra busteado agora',
#  'quem nunca ne presida..',
#  'minhas buscas recentes estao só risadinha de canto',
#  'cheira uns oleos essentials',
#  'a industria do guarana jesus criou o covid (eh a segunda pessoa q fala de refri)',
#  'idkdkkdkd essa conversa virou um desses chats q vc responde todo dia ne desculpa... eh a oportunidade..',
#  'eu to zerando meu limite tem um ano já e esses safados nao aumentam... e eu preciso comprar equip pra pada…',
#  'bruno qual a magia pra aumentar o limite eu já fiz de tudo...',
#  'cheirando tudo igual um cao agora',
#  '',
#  'kkkkkka a babi contou... achei q foi bom entao!!',
#  'nossa olha a pao ai',
#  'eu to a semana toda desiludido com a vida tudo virou textura... hj to sentindo levemente coisas bem especificas',
#  'a minha recentemente ficou viciada na tomada a sua tb? qual nome da sua?',
#  'lindo ver a jbl preta e me identificar tanto...',
#  '(yn)',
#  'microbrio vegano',
#  'pensei em desenvolver poderes imagina',
#  'bicho fica cheirando coisas assim separa casca de laranja num pote / cafe em outro / coisas assim abre cheira e lembra',
#  'QUANTO TEMPO JA',
#  'meu deus quanto tempo ja',
#  'completamente abobalhado das ideias caso nao retome cheiro e gosto das coisas pq simplesmente a covid mexe no NERVO…',
#  'ele eh desses mesmo... intenso',
#  '"qual foi minha filha so to indo pegar o metro da licença"',
#  'beleza saiu de qual programinha de comedia de auditorio',
#  'Olá, é a primeira vez que a cultura nordestina está conquistando o país todo, a nossa música finalmente encantou o…',
#  'MARCOSSSS',
#  'ihhhh',
#  'beleza curtiu o donda mas e a saudade da dinda?',
#  'vontade louca de ter um filho',
#  'rodou a chavinha e todo mundo ao meu lado é Fit o que está ocorrendo',
#  'nossa como eh bom voltar a trabalhar nem acredito que essa frase faz muito sentido',
#  'sim..',
#  'desculpa..',
#  'esse eh ótimo..',
#  'gente q pede desculpa por tudo 🥵🥵',
#  "queria te dar o p'ao da pa'o",
#  'a dor machuca..',
#  'sim nao gostou ?',
#  'obrigraze...',
#  'como me conquistar pela boca bolo: nao sinto cheiro doce: nao sinto gosto sorvete: nao sinto cheiro chocolate: na…',
#  'caraca o maníaco...',
#  'rave monstra em jupiter',
#  'senador heinze ainda não sabe que a vacina impede internação e não contágio',
#  'eh o nosso sartre botafoguense',
#  '',
#  'donda',
#  'sera q o seu twitter vai ser lacrado assim',
#  'mais de 8 anos nerd oq vc acha',
#  'dps de muitos anos me achei bonito e só foi possível com um filtro do instagram achei brega o suspiro da auto estim…',
#  'vc eh fruto deste negocio..',
#  'q demorava 2 dia pra baixar o kRO e mais 3 dias pra baixar o Sak',
#  'cries in prontera theme song',
#  'ultimo mes de compras tulleceria #eufui',
#  'o presidente atirou em dois gatinhos filhotes e esganou um bebê mas fique ATENTO mais uma cortina de fumaça',
#  'ele so quer acabar o sofrimento da existencia os antepassados corriam livre agora ele mora num 60m2 ouvindo podcast o dia todo',
#  '',
#  'eles estao loucos pra se jogar do trigésimo andar mas botaram redes ali',
#  'ja pensou que o seu querido pet detesta viver e sempre que te olha ele quer menos estar vivo voce vem fazendo voz f…',
#  'daí que não pagava impostinho rsrs',
#  'tô quase',
#  'ih amiga passaram viu',
#  'lembra quando voces falaram que Não Passarão??',
#  'rabo de galo em inglês é cock tail, qual sua opinião sobre coquetel? — o amarelinho bar aqui de cabo frio faz o rab…',
#  'amigo deve ser difícil de costurar esse',
#  'e um pao que cada % de farinha eh um dia com covid',
#  'me diz algo estou consumido pela tristeza do tédio e pelo tédio da tristeza..',
#  'minua cNbeca nao para nao ocnsigo deitar preciso trabalhar',
#  'nao contente o mes de agosto gigante se arrasta e ele acaba dia 31 trinta e um mais um dia e mais um motivo por ele ser eterno',
#  'muito triste existir dentro de uma cabeça ansiosa "e se esses dias de quarentena virasse um roteiro?" "o que posso…',
#  'o cara veio aqui e disse que o router queimou pelo apagao as vezes foi isso aí',
#  'tw como ai?',
#  'acho q eh o meu fimsabia..',
#  'obrigado deus pela covid e pela oscilação da internet não me resta nada mais',
#  'Analista de mercado financeiro (CNPI e CMT level 3 candidate). Passei pelas maiores corretoras do Brasil e do Mundo.',
#  'sim',
#  'arrasado com desenhozinho',
#  'assim hoje',
#  '??',
#  'post rock comendo solto na espera da assistencia técnica da sumicity',
#  'claro que é abelha',
#  'nunca vi tanta gente animada por gospel',
#  'que md gostoso',
#  'sabor quando nois cava areia da praia e acha aquele lamaçal preto',
#  'Vaai rolaaaaaaarrrr 🤝😳🙏🏼😜🤙 ;)))))',
#  'que inconveniente cobrando os amigo...',
#  'é curioso como as relações com as coisas vao mudando tipo nao achava que iria descobrir mais coisas no meu quarto e…',
#  'vai rola!!',
#  'ELE!!',
#  'o unico cara q usa mozilla no mobile',
#  'tomei distraído',
#  'sim..',
#  'me perdi no peprsonagemm..',
#  'eu uso um wallpaper que simula o içphone eu juro',
#  "don't break the chain: wallpaper, last song, 7th picture and 7 moots(sem isso)",
#  'me recuso',
#  'por favor uma pilha AA para introduzir na minha maquina wahl',
#  'BORA!! rifa cheia de coisa gostosa (vegana) aqui da região pra grana ir pro . tem pao, tem bolo, tem…',
#  'bozarrio',
#  'Acabou de publicar uma foto em Região dos Lagos',
#  'OIEEEEEEE',
#  'eu te amo muito voce eh o amor da minha vida',
#  'sei que é uma conversa antiga rsrs mas: o posicionamento do gancho em relação ao tacho é…',
#  'troco masseira reemaq ar25 numa masseira famag 18k 😎',
#  'claramente endoidou na idade de usar droga na facul de artes',
#  'foi fazer feira com a namorada 🥺🥺',
#  'sempre que acordo agradeço ao código de postura do município de cabo frio por não deixar os prédios ultrapassarem 3…',
#  'zucrilhos',
#  'sim !',
#  'so quer saber de ser mae de pet',
#  'muito gado 💓',
#  'O cabelo grande está ligado à nossa liberdade na vida. Ele tornou-se um símbolo de independência, abertura…',
#  'o leite de soja estava estragado? a batata estava sem sal? se morder o brocolis cru eu ganho mais nutrientes? pra que vou assar as coisas?',
#  'precisamos falar sobre a liberdade de tentar se alimentar sem sentir gosto de nada',
#  'eu nao aguento mais faz esse pesadelo parar',
#  'sai fora irmao eu sou casado',
#  'boa noite',
#  'ja chegou na gata e falou "que energia maravilhosa voce me passa"',
#  'ola senhor mosquito posso saber o que queres em mimhas pernas',
#  'caiu na rede e peixe',
#  'Homens chinelos casal praia sapatos de lona chinelo mulher casal preto cinza desliza pés largos chinelos homem',
#  'uma vez marinei a cenôra esqueci por 4 dias embalsamado no shoyu e eu fiz o xorro quente.. tava só o azedume..',
#  'palavrinhas na sua tela',
#  'mandar um pix nao manda..',
#  'a,miga me ajuda a usar as hsashtags ...',
#  'tu tem link pra tudo irmao',
#  'cada dia mais TENTADO ao mundo do tiktok mas sei que nao posso..',
#  '',
#  '7,4 pps (paixoes por segundo)',
#  'namoral vou junta as coisa mais saudavel e nojentas do mundo e comer',
#  '🙏🏼💓',
#  'amiga vc ja comia essas papinha...pesto na faca...',
#  'ele mesmo',
#  'sim!',
#  'ai nanoral qual a graca de comer quando nao se sente gosto de NADAAA',
#  '2021 meu pai pedindo pra baixar o corel no pc',
#  'esse eh o tal do Match que os jovens falam',
#  'ora ora quem diria que parar de trabalhar no computador 8h por dia me faria AMAR ficar de frente com ele de novo !!',
#  'fiquei estarrecido com essa hoje',
#  'tamer como ta o coraçao — as vezes sinto uma pontada assim pois ontem de manha quando a covid impctou meu corpo com…',
#  'e quando eu fui demitido do emprego e o chefe literalmente lançou "eh que voces millennials sao muito contestadores eu entendo ..."',
#  'esse eu quero !!',
#  'kkk a mesa dos sogado toda cuspida de covid',
#  'you used to get itin your fishnets...',
#  '',
#  '🤝',
#  'sentindo o nariz quentinho... eh a febre.. olho quentinho... ate mais desejem-me sorte',
#  'sai fora apagao todo dia isso',
#  'to brincando etnendi ..',
#  'a´rende a escrevre amor nao da pra entesdnder nada oq falas..',
#  'por isso apaixonado por cozinha ..',
#  'ah nao lala 20h30 da noite',
#  'gladison roubou sua mulher pra estar com tanta raiva assim ?',
#  'vai no quiro pra fechar',
#  'eu juro queposso explicar',
#  "viciado em reagir com olhos de coraçao n'outra rede",
#  'Ą̴̫̘͓̦̱҇͂̒͌̀A̴̧̛͕͉̙̎̒͗̏A̸͉̟̬͊̿̽͜͠A̷̡͚͓̽̏͞A̸̧̫͙̝̳͑͌͋͠Ą̴̫̘͓̦̱҇͂̒͌̀A̴̧̛͕͉̙̎̒͗̏A̸͉̟̬͊̿̽͜͠A̷̡͚͓̽̏͞A̸̧̫͙̝̳͑͌͋͠iii que fominha..',
#  'tatua metade da tatuagem em uma pessoa enquanto ela tatua alguem faça a centopeia humana da piramide',
#  'putz a aura e aquela confortavel no narizinho ne agora entendi..',
#  'as vezes queria poder ler uma materia do intercept sem ter uma intro absurda que parece um grande romance italiano',
#  'babado e forte lulu',
#  '',
#  'caralhowetwetetwwettwe eu preciso disso na minha mesaaaaaaaaaaaaaaaaaaaa',
#  'putz acabamo de fazer a big compra',
#  'sao as boas vindas seja bem vindo a cabo frio',
#  'vc um dia vai me perdoar ?',
#  'quero tatuar um biscoito cream cracker que onde estaria escrito cream cracker no biscoito estaria escrito na verdad…',
#  'o q vai cura eh um pombo comendo creme crake na mi nha perna',
#  'maios uma vez vitamina . com salvando minha longa vida',
#  'mary kay é exploração da força de trabalho mesmo',
#  'vamos fazer uma piramide',
#  'sem contar que o dinheiro inicial da pirâmide provavelmente vem de lavagem... e o resto do…',
#  'a parada é que nesse esquema vc não é "obrigado" a achar alguém (talvez pq não exista esse…',
#  'aí provavelmente algum banco que patrocina a globo pagou alguma matéria e ele tomou dois exposeds do fantastico seguidos...',
#  'e o legal de ser criptomoeda é que ninguém entende basicamente, então ninguém corre atras pra saber de…',
#  'poddia ter entrado nessa ne botar eses curriculo pra ganha grana',
#  'os malucos que prometiam 20, 30% são mortos e tal. provavelmente o cara pagava só 10% pq o resto ia pr…',
#  'por isso que é sempre suspeito quando alguém do nada começa a prometer uma % muito alta de lucro por m…',
#  'então você consegue lavar dinheiro de tráfico dentro dessa pirâmide. consegue fazer o que quiser. as p…',
#  'como criptomoeda não é algo que você de fato consegue comprovar transação, esse seria o produto fake d…',
#  'no caso da herbalife o produto é caro e fake e só sobrevive do marketing, mas ainda assim é um produto…',
#  'pensa na herbalife: ela tem um produto, o cara no topo da pirâmide vende esse produto pra alguém abaix…',
#  'como faço pra te esse cabelinho do cri',
#  'se junta ao bonde proteste',
#  'kkkkkkkkkkkkkkkkkkkkcjgvjgfkfgkkkkkkkkkkk',
#  'quantos clientes da paõ padaria pagavam pão com glaid money??',
#  'sim numa bela casa na moringa',
#  'eu nao aguento mais a realidade eh incrivel',
#  'em cabo frio vc tem: praia e vento sabe o que tem tb em cabo frio? tremzinho estilo carreta furacao pedindo pra sol…',
#  '😎',
#  'essa eh boa tb e s[o da pra fazer u ma boa nesse frigideira q gruda uma na otra',
#  'nossa eh a coisa mais util do MUNDO eu amo',
#  'a covid vai me proporcionar todos meuis animes em dia..',
#  'DROGA',
#  'explodi',
#  'o seu pediatra batia na sua barriguinha pra solta gases',
#  'mandando boas energias para tua saga da *****',
#  'cade',
#  'temer to conversando com uma menina aqui ela pediu meu nude posso mandar pra voce e voce manda pra ela — sim inclus…',
#  'odeio demais o advento do zap q deixa as conversas la e da pra ler de novo ouvir de novo ver denovo pq eu gosto d……',
#  'SUDOESTEEEE',
#  'caraca eh um absurdo recebi 20 ligações da operadora hoje e umas 3 mensagens de voz que vc so pode ouvir pagando e…',
#  'o maluco lavando dinheiro na universal e os cara nessa',
#  'ikkkkkkkkkkkkkk bicho olha o nivel do debate',
#  'PEQUENA EMPRESA CAPITAL SOCIAL 7.5 BI',
#  'e nao sabem pra onde o dinheirinho vai tb 🤡 daqui a pouco cabo frio ta cheio de milicia mas geral eh #forabolsonaro',
#  'a teoria era que "os caras que apostam em 25-30% ao mês sao mt faceis de serem pegos, o meu promete só 1…',
#  'bicho metade de cabo frio ta nessa eh obvio q ia dar errado',
#  'the house caiu',
#  '',
#  'italiana',
#  'o capixaba disse que nao tem nem dende nem leite de coco... isso eh uma releitura da bahia..',
#  'sinistro',
#  'anti pfizer',
#  'e hoje que fui informado que moqueca na verdade eh um ratatouille de tomate cebola e coentro',
#  'ok',
#  'esses cara tao de brincadeira',
#  '🤣🤣🤣🤣🤣',
#  'longe de casa eu vou me encontrar com',
#  'meninos gosta de real emo meninas tb',
#  'repitam comigo tudo que thais oyama noticiar é besteira',
#  'dei uma topada que nossa santa maria mae de deus rogai por nos pecadores',
#  'onde nasce o Homem',
#  'o desejo e inconsciente rici',
#  'desejo não é questão de vontade',
#  'lancei uma moqueca intensa e agora eh redinha enquanto pao fermenta eh a vida que deus me deu..',
#  'gostosa',
#  'ganhoy mais un unfolou',
#  ...]

# %%
filtered = filter_data(data)

# %%
print('sentences', len(data))
# Out:
# sentences 3217

# %%
tokens = set()
for sentence in filtered:
    for token in sentence.split():
        tokens.add(token)
print('unique tokens', len(tokens))
# Out:
# unique tokens 6734

# %%
tokens = 0
for sentence in filtered:
    for token in sentence.split():
        tokens += 1
print('tokens', tokens)
# Out:
# tokens 20760

# %%
from gensim.test.utils import common_texts
from gensim.models import Word2Vec

tokenize = [el.split() for el in filtered]
word2vecmodel = Word2Vec(sentences=tokenize, vector_size=VECTOR_SIZE, window=WINDOW_SIZE, min_count=1, workers=4)
word2vecmodel.save("word2vec.model")

# %%
word2vecmodel.wv["rodrigo"]
# Out:
# array([-1.92692149e-02, -4.92732972e-04,  7.13205989e-03,  4.98202862e-03,
#         6.38224510e-03, -3.08877532e-03,  1.76255517e-02, -9.02063213e-03,
#         5.02520939e-03,  1.80281624e-02, -1.17477505e-02, -1.43473679e-02,
#        -2.87673157e-03, -1.02068707e-02, -3.86691443e-03, -8.15747990e-06,
#        -2.37499597e-04, -8.26955959e-03,  4.54729749e-03,  6.76459027e-03,
#        -1.26251122e-02, -1.50042784e-03,  4.63921065e-03, -1.51749386e-03,
#        -1.24564786e-02, -1.03594153e-03,  4.41692118e-03, -3.47987260e-03,
#         9.35728941e-03, -1.33218849e-02, -1.14282435e-02,  8.55650287e-03,
#         1.83472261e-02,  1.60617486e-03, -1.00993374e-02,  1.44411996e-02,
#         2.24970188e-03,  1.47100259e-03,  1.08733065e-02, -2.06863065e-03,
#        -1.73499179e-03, -7.80369574e-03,  1.11945262e-02, -1.19739026e-02,
#        -2.33176490e-03,  5.54237096e-03,  1.94345263e-03, -5.17491484e-04,
#         1.64811220e-02,  2.00692229e-02], dtype=float32)

# %%
word2vecmodel.wv.most_similar('tamer', topn=10)
# Out:
# [('milenares', 0.5590617060661316),
#  ('chicago', 0.48981714248657227),
#  ('ciclo', 0.4631543755531311),
#  ('letras', 0.4432130753993988),
#  ('LIVRE', 0.43657276034355164),
#  ('explica', 0.42867186665534973),
#  ('abobado', 0.4201488196849823),
#  ('vcs!!', 0.41772836446762085),
#  ('abuso', 0.4150388240814209),
#  ('fom', 0.4141755700111389)]

# %%
def to_input(tokens):
    inputs = []
    for i in range(0, len(tokens)-INPUT_TOKEN_SIZE, 1):
        inputs.append(tokens[i:i+INPUT_TOKEN_SIZE+1])
    return inputs

# %%
tokens_sentence = []
for token in tokenize:
    tokens_sentence.extend(to_input(token))

# %%
tokens_sentence
# Out:
# [['12:39', 'ainda', 'nao', 'reclamei', 'de', 'nada'],
#  ['ainda', 'nao', 'reclamei', 'de', 'nada', 'libertador'],
#  ['nao', 'reclamei', 'de', 'nada', 'libertador', '...'],
#  ['a', 'sua', 'nao', 'ouvi', 'o', 'desfecho'],
#  ['sua', 'nao', 'ouvi', 'o', 'desfecho', 'da'],
#  ['nao', 'ouvi', 'o', 'desfecho', 'da', 'sua'],
#  ['ouvi', 'o', 'desfecho', 'da', 'sua', 'boca!!'],
#  ['um', 'brinde', 'a', 'minha', 'intuição', '🥂'],
#  ['vc', 'tem', 'o', 'mesmo', 'nome', 'da'],
#  ['tem', 'o', 'mesmo', 'nome', 'da', 'gata'],
#  ['o', 'mesmo', 'nome', 'da', 'gata', 'da'],
#  ['mesmo', 'nome', 'da', 'gata', 'da', 'minha'],
#  ['nome', 'da', 'gata', 'da', 'minha', 'vó'],
#  ['todo', 'cabofriense', 'tem', 'cara', 'de', 'que'],
#  ['cabofriense', 'tem', 'cara', 'de', 'que', 'Perdeu'],
#  ['tem', 'cara', 'de', 'que', 'Perdeu', 'Tudo'],
#  ['cara', 'de', 'que', 'Perdeu', 'Tudo', 'na'],
#  ['de', 'que', 'Perdeu', 'Tudo', 'na', 'gas'],
#  ['que', 'Perdeu', 'Tudo', 'na', 'gas', 'consultoria'],
#  ['amoo', 'claudinha', 'minha', 'orientadora', 'o', 'design'],
#  ['claudinha', 'minha', 'orientadora', 'o', 'design', 'desistiu'],
#  ['minha', 'orientadora', 'o', 'design', 'desistiu', 'dela'],
#  ['orientadora', 'o', 'design', 'desistiu', 'dela', 'ou'],
#  ['o', 'design', 'desistiu', 'dela', 'ou', 'ela'],
#  ['design', 'desistiu', 'dela', 'ou', 'ela', 'desistiu'],
#  ['desistiu', 'dela', 'ou', 'ela', 'desistiu', 'do'],
#  ['dela', 'ou', 'ela', 'desistiu', 'do', 'design'],
#  ['quem', 'eh', 'esse', 'tal', 'de', 'edipo'],
#  ['eh', 'esse', 'tal', 'de', 'edipo', 'ele'],
#  ['esse', 'tal', 'de', 'edipo', 'ele', 'quer'],
#  ['tal', 'de', 'edipo', 'ele', 'quer', 'me'],
#  ['de', 'edipo', 'ele', 'quer', 'me', 'comer'],
#  ['ai', 'joga', 'pro', 'místico', 'e', 'firma'],
#  ['joga', 'pro', 'místico', 'e', 'firma', 'com'],
#  ['pro', 'místico', 'e', 'firma', 'com', 'os'],
#  ['místico', 'e', 'firma', 'com', 'os', 'olhos'],
#  ['e', 'firma', 'com', 'os', 'olhos', '"espelho'],
#  ['firma', 'com', 'os', 'olhos', '"espelho', 'quebrado'],
#  ['com', 'os', 'olhos', '"espelho', 'quebrado', 'anos'],
#  ['os', 'olhos', '"espelho', 'quebrado', 'anos', 'de'],
#  ['olhos', '"espelho', 'quebrado', 'anos', 'de', 'azar"'],
#  ['coloque-os', 'ali', 'no', 'lugar', 'de', 'pés'],
#  ['eh', 'um', 'convite', 'a', 'auto', 'reflexão'],
#  ['dona', 'esse', 'fogao', 'ta', 'quase', 'bom'],
#  ['esse', 'fogao', 'ta', 'quase', 'bom', 'so'],
#  ['fogao', 'ta', 'quase', 'bom', 'so', 'nao'],
#  ['ta', 'quase', 'bom', 'so', 'nao', 'presta'],
#  ['quase', 'bom', 'so', 'nao', 'presta', '3'],
#  ['bom', 'so', 'nao', 'presta', '3', 'boca'],
#  ['desculpe', 'senhora', 'Nao', 'gosto', 'de', 'pes'],
#  ['amo', 'vc!!!', 'e', 'seu', 'pombo', 'novo'],
#  ['homem', 'eh', 'igual', 'fone', 'de', 'ouvido'],
#  ['eh', 'igual', 'fone', 'de', 'ouvido', 'comprei'],
#  ['igual', 'fone', 'de', 'ouvido', 'comprei', 'um'],
#  ['fone', 'de', 'ouvido', 'comprei', 'um', 'airdots'],
#  ['de', 'ouvido', 'comprei', 'um', 'airdots', 'da'],
#  ['ouvido', 'comprei', 'um', 'airdots', 'da', 'redmi'],
#  ['comprei', 'um', 'airdots', 'da', 'redmi', 'falso'],
#  ['um', 'airdots', 'da', 'redmi', 'falso', 'e'],
#  ['airdots', 'da', 'redmi', 'falso', 'e', 'fui'],
#  ['da', 'redmi', 'falso', 'e', 'fui', 'ressarcido'],
#  ['redmi', 'falso', 'e', 'fui', 'ressarcido', 'pelo'],
#  ['falso', 'e', 'fui', 'ressarcido', 'pelo', 'marketplace'],
#  ['e', 'fui', 'ressarcido', 'pelo', 'marketplace', 'da'],
#  ['fui', 'ressarcido', 'pelo', 'marketplace', 'da', 'americanas'],
#  ['ok', 'nenene', 'zuckerberg', 'lelelele', 'rede', 'social'],
#  ['nenene', 'zuckerberg', 'lelelele', 'rede', 'social', 'nananana'],
#  ['zuckerberg', 'lelelele', 'rede', 'social', 'nananana', 'estamos'],
#  ['lelelele', 'rede', 'social', 'nananana', 'estamos', 'trabalhando'],
#  ['rede', 'social', 'nananana', 'estamos', 'trabalhando', 'de'],
#  ['social', 'nananana', 'estamos', 'trabalhando', 'de', 'graca'],
#  ['nananana', 'estamos', 'trabalhando', 'de', 'graca', 'etc'],
#  ['estamos', 'trabalhando', 'de', 'graca', 'etc', 'mas'],
#  ['trabalhando', 'de', 'graca', 'etc', 'mas', 'muito'],
#  ['de', 'graca', 'etc', 'mas', 'muito', 'gostoso'],
#  ['graca', 'etc', 'mas', 'muito', 'gostoso', 'ver'],
#  ['etc', 'mas', 'muito', 'gostoso', 'ver', 'a'],
#  ['mas', 'muito', 'gostoso', 'ver', 'a', 'infancia'],
#  ['muito', 'gostoso', 'ver', 'a', 'infancia', 'dos'],
#  ['gostoso', 'ver', 'a', 'infancia', 'dos', 'coleguinha...'],
#  ['feliz', 'com', 'choco', 'triste', 'sem', 'choco'],
#  ['somos', 'apejas', 'jovens', 'pirados', 'da', 'nossa'],
#  ['apejas', 'jovens', 'pirados', 'da', 'nossa', 'geracao..'],
#  ['eu', 'tenho', 'a', 'maior', 'vertigem', 'do'],
#  ['tenho', 'a', 'maior', 'vertigem', 'do', 'mundo'],
#  ['a', 'maior', 'vertigem', 'do', 'mundo', 'potencializei'],
#  ['maior', 'vertigem', 'do', 'mundo', 'potencializei', 'numa'],
#  ['vertigem', 'do', 'mundo', 'potencializei', 'numa', 'oficina'],
#  ['do', 'mundo', 'potencializei', 'numa', 'oficina', 'de'],
#  ['mundo', 'potencializei', 'numa', 'oficina', 'de', 'iluminacao'],
#  ['potencializei', 'numa', 'oficina', 'de', 'iluminacao', 'q'],
#  ['numa', 'oficina', 'de', 'iluminacao', 'q', 'tive'],
#  ['oficina', 'de', 'iluminacao', 'q', 'tive', 'q'],
#  ['de', 'iluminacao', 'q', 'tive', 'q', 'subir'],
#  ['iluminacao', 'q', 'tive', 'q', 'subir', 'uma'],
#  ['q', 'tive', 'q', 'subir', 'uma', 'escada'],
#  ['tive', 'q', 'subir', 'uma', 'escada', 'gigante'],
#  ['não', 'aguento', 'mais', 'ouvir', 'Djavan', '-'],
#  ['aguento', 'mais', 'ouvir', 'Djavan', '-', 'Maçã'],
#  ['mais', 'ouvir', 'Djavan', '-', 'Maçã', 'do'],
#  ['ouvir', 'Djavan', '-', 'Maçã', 'do', 'Rosto'],
#  ['Djavan', '-', 'Maçã', 'do', 'Rosto', 'e'],
#  ['-', 'Maçã', 'do', 'Rosto', 'e', 'agora'],
#  ['Maçã', 'do', 'Rosto', 'e', 'agora', 'preciso'],
#  ['do', 'Rosto', 'e', 'agora', 'preciso', 'aprender'],
#  ['Rosto', 'e', 'agora', 'preciso', 'aprender', 'a'],
#  ['e', 'agora', 'preciso', 'aprender', 'a', 'dançar'],
#  ['agora', 'preciso', 'aprender', 'a', 'dançar', 'forró'],
#  ['orgulhoso', 'do', 'título', 'Bobão', 'pra', 'Idade'],
#  ['no', 'final', 'a', 'voz', 'de', 'choro!!!!!'],
#  ['como', 'um', 'bom', 'barco', 'no', 'mar..'],
#  ['um', 'bom', 'barco', 'no', 'mar..', 'eu'],
#  ['bom', 'barco', 'no', 'mar..', 'eu', 'vo..'],
#  ['barco', 'no', 'mar..', 'eu', 'vo..', 'eu'],
#  ['no', 'mar..', 'eu', 'vo..', 'eu', 'vo'],
#  ['me', 'encontro', 'no', 'pico', 'da', 'glicose'],
#  ['encontro', 'no', 'pico', 'da', 'glicose', 'com'],
#  ['no', 'pico', 'da', 'glicose', 'com', 'docinho'],
#  ['pico', 'da', 'glicose', 'com', 'docinho', 'de'],
#  ['da', 'glicose', 'com', 'docinho', 'de', 'leite'],
#  ['glicose', 'com', 'docinho', 'de', 'leite', 'de'],
#  ['com', 'docinho', 'de', 'leite', 'de', 'inhame'],
#  ['docinho', 'de', 'leite', 'de', 'inhame', 'em'],
#  ['de', 'leite', 'de', 'inhame', 'em', 'plena'],
#  ['leite', 'de', 'inhame', 'em', 'plena', 'aldeia'],
#  ['de', 'inhame', 'em', 'plena', 'aldeia', 'velha'],
#  ['call', 'me', 'mister', 'chicken', 'little', 'em'],
#  ['me', 'mister', 'chicken', 'little', 'em', 'ingles'],
#  ['mister', 'chicken', 'little', 'em', 'ingles', 'super'],
#  ['chicken', 'little', 'em', 'ingles', 'super', 'heroi'],
#  ['o', 'motorista', 'gente', 'boa', 'de', 'bonezinho'],
#  ['motorista', 'gente', 'boa', 'de', 'bonezinho', 'ex'],
#  ['gente', 'boa', 'de', 'bonezinho', 'ex', 'funcionário'],
#  ['boa', 'de', 'bonezinho', 'ex', 'funcionário', 'da'],
#  ['de', 'bonezinho', 'ex', 'funcionário', 'da', 'cedae'],
#  ['bonezinho', 'ex', 'funcionário', 'da', 'cedae', 'fala'],
#  ['ex', 'funcionário', 'da', 'cedae', 'fala', 'muito'],
#  ['funcionário', 'da', 'cedae', 'fala', 'muito', 'fala'],
#  ['da', 'cedae', 'fala', 'muito', 'fala', 'feliz'],
#  ['cedae', 'fala', 'muito', 'fala', 'feliz', 'sorri'],
#  ['fala', 'muito', 'fala', 'feliz', 'sorri', 'com'],
#  ['muito', 'fala', 'feliz', 'sorri', 'com', 'a'],
#  ['fala', 'feliz', 'sorri', 'com', 'a', 'fala'],
#  ['feliz', 'sorri', 'com', 'a', 'fala', 'diz'],
#  ['sorri', 'com', 'a', 'fala', 'diz', 'que'],
#  ['com', 'a', 'fala', 'diz', 'que', 'bolsonaro…'],
#  ['caraca', 'eu', 'amOOOA', 'lotada', 'como', 'que'],
#  ['eu', 'amOOOA', 'lotada', 'como', 'que', 'pode'],
#  ['amOOOA', 'lotada', 'como', 'que', 'pode', 'que'],
#  ['lotada', 'como', 'que', 'pode', 'que', 'coisa'],
#  ['como', 'que', 'pode', 'que', 'coisa', 'mais'],
#  ['que', 'pode', 'que', 'coisa', 'mais', 'gostosa'],
#  ['nesse', 'pique', 'que', 'vamo', 'inclusive', 'da'],
#  ['pique', 'que', 'vamo', 'inclusive', 'da', 'próxima'],
#  ['que', 'vamo', 'inclusive', 'da', 'próxima', 'o'],
#  ['vamo', 'inclusive', 'da', 'próxima', 'o', 'pilantra'],
#  ['inclusive', 'da', 'próxima', 'o', 'pilantra', 'estara'],
#  ['da', 'próxima', 'o', 'pilantra', 'estara', 'trajado'],
#  ['próxima', 'o', 'pilantra', 'estara', 'trajado', 'do'],
#  ['o', 'pilantra', 'estara', 'trajado', 'do', 'Manto'],
#  ['kdkkdkd', 'sim', 'mas', 'nao', 'eh', 'Saber'],
#  ['sim', 'mas', 'nao', 'eh', 'Saber', 'eh'],
#  ['mas', 'nao', 'eh', 'Saber', 'eh', 'Trabalhar'],
#  ['nao', 'eh', 'Saber', 'eh', 'Trabalhar', 'com..'],
#  ['meu', 'deus', 'tudo', 'foi', 'retorcido', 'no'],
#  ['deus', 'tudo', 'foi', 'retorcido', 'no', 'buraco'],
#  ['tudo', 'foi', 'retorcido', 'no', 'buraco', 'negro'],
#  ['moderadOR', 'TIRA', 'O', 'MOLEQUE', 'DESSE', 'GRUPO'],
#  ['TIRA', 'O', 'MOLEQUE', 'DESSE', 'GRUPO', 'AGORAAAAAAAAAA'],
#  ['com', 'medo', 'de', 'pedir', 'carona', 'pra'],
#  ['medo', 'de', 'pedir', 'carona', 'pra', 'casimiro'],
#  ['de', 'pedir', 'carona', 'pra', 'casimiro', 'de'],
#  ['pedir', 'carona', 'pra', 'casimiro', 'de', 'abreu'],
#  ['carona', 'pra', 'casimiro', 'de', 'abreu', 'e'],
#  ['pra', 'casimiro', 'de', 'abreu', 'e', 'acharem'],
#  ['casimiro', 'de', 'abreu', 'e', 'acharem', 'que'],
#  ['de', 'abreu', 'e', 'acharem', 'que', 'estou'],
#  ['abreu', 'e', 'acharem', 'que', 'estou', 'comentando'],
#  ['e', 'acharem', 'que', 'estou', 'comentando', 'um'],
#  ['acharem', 'que', 'estou', 'comentando', 'um', 'react'],
#  ['que', 'estou', 'comentando', 'um', 'react', 'de'],
#  ['estou', 'comentando', 'um', 'react', 'de', 'hamburguer'],
#  ['comentando', 'um', 'react', 'de', 'hamburguer', 'coreano'],
#  ['tenho', 'o', 'duro', 'dever', 'de', 'abastecer'],
#  ['o', 'duro', 'dever', 'de', 'abastecer', 'meus'],
#  ['duro', 'dever', 'de', 'abastecer', 'meus', 'dois'],
#  ['dever', 'de', 'abastecer', 'meus', 'dois', 'amigos'],
#  ['de', 'abastecer', 'meus', 'dois', 'amigos', 'com'],
#  ['abastecer', 'meus', 'dois', 'amigos', 'com', 'fofocas'],
#  ['meus', 'dois', 'amigos', 'com', 'fofocas', 'e'],
#  ['dois', 'amigos', 'com', 'fofocas', 'e', 'novidades'],
#  ['amigos', 'com', 'fofocas', 'e', 'novidades', 'sobre'],
#  ['com', 'fofocas', 'e', 'novidades', 'sobre', 'minha'],
#  ['fofocas', 'e', 'novidades', 'sobre', 'minha', 'vida'],
#  ['e', 'novidades', 'sobre', 'minha', 'vida', 'a'],
#  ['novidades', 'sobre', 'minha', 'vida', 'a', 'cada'],
#  ['sobre', 'minha', 'vida', 'a', 'cada', 'semana'],
#  ['minha', 'vida', 'a', 'cada', 'semana', 'mal'],
#  ['vida', 'a', 'cada', 'semana', 'mal', 'sabem'],
#  ['a', 'cada', 'semana', 'mal', 'sabem', 'q…'],
#  ['abri', 'o', 'guarda', 'roupa', 'do', 'moreno'],
#  ['o', 'guarda', 'roupa', 'do', 'moreno', 'eh'],
#  ['guarda', 'roupa', 'do', 'moreno', 'eh', 'só'],
#  ['roupa', 'do', 'moreno', 'eh', 'só', 'camisa'],
#  ['do', 'moreno', 'eh', 'só', 'camisa', 'do'],
#  ['moreno', 'eh', 'só', 'camisa', 'do', 'vascao'],
#  ['por', 'isso', 'tu', 'ta', 'tendo', 'aulinha'],
#  ['isso', 'tu', 'ta', 'tendo', 'aulinha', 'eh.....'],
#  ['beijando', 'gente', 'que', 'costura', 'alo', 'mamãe'],
#  ['gente', 'que', 'costura', 'alo', 'mamãe', 'e'],
#  ['que', 'costura', 'alo', 'mamãe', 'e', 'vovó'],
#  ['costura', 'alo', 'mamãe', 'e', 'vovó', 'freud'],
#  ['alo', 'mamãe', 'e', 'vovó', 'freud', 'intensifies'],
#  ['essa', 'eh', 'a', 'famosa', 'Dar', 'uma'],
#  ['eh', 'a', 'famosa', 'Dar', 'uma', 'azeitada'],
#  ['acordei', 'hoje', 'rindo', 'da', 'interação', 'de'],
#  ['hoje', 'rindo', 'da', 'interação', 'de', 'voces'],
#  ['rindo', 'da', 'interação', 'de', 'voces', 'hj'],
#  ['da', 'interação', 'de', 'voces', 'hj', 'a'],
#  ['interação', 'de', 'voces', 'hj', 'a', 'tarde'],
#  ['de', 'voces', 'hj', 'a', 'tarde', 'cresceram'],
#  ['voces', 'hj', 'a', 'tarde', 'cresceram', 'duas'],
#  ['hj', 'a', 'tarde', 'cresceram', 'duas', 'espinuas'],
#  ['a', 'tarde', 'cresceram', 'duas', 'espinuas', 'enormes'],
#  ['tarde', 'cresceram', 'duas', 'espinuas', 'enormes', 'no'],
#  ['cresceram', 'duas', 'espinuas', 'enormes', 'no', 'meu'],
#  ['duas', 'espinuas', 'enormes', 'no', 'meu', 'rosto'],
#  ['espinuas', 'enormes', 'no', 'meu', 'rosto', 'va'],
#  ['enormes', 'no', 'meu', 'rosto', 'va', 'se'],
#  ['no', 'meu', 'rosto', 'va', 'se', 'fuder'],
#  ['quando', 'o', 'prof', 'de', 'natacao', 'fala'],
#  ['o', 'prof', 'de', 'natacao', 'fala', 'Faz'],
#  ['prof', 'de', 'natacao', 'fala', 'Faz', 'mais'],
#  ['de', 'natacao', 'fala', 'Faz', 'mais', '4'],
#  ['natacao', 'fala', 'Faz', 'mais', '4', 'crawlzinho'],
#  ['fala', 'Faz', 'mais', '4', 'crawlzinho', '🥺🥺🥺'],
#  ['caraca', 'eu', 'sou', 'completamente', 'lelé', 'da'],
#  ['eu', 'sou', 'completamente', 'lelé', 'da', 'cuca'],
#  ['sou', 'completamente', 'lelé', 'da', 'cuca', 'marquei'],
#  ['completamente', 'lelé', 'da', 'cuca', 'marquei', 'uma'],
#  ['lelé', 'da', 'cuca', 'marquei', 'uma', 'viagem'],
#  ['da', 'cuca', 'marquei', 'uma', 'viagem', 'na'],
#  ['cuca', 'marquei', 'uma', 'viagem', 'na', 'frente'],
#  ['marquei', 'uma', 'viagem', 'na', 'frente', 'fria'],
#  ['ir', 'no', 'cabeleliro', 'dps', 'de', '16'],
#  ['no', 'cabeleliro', 'dps', 'de', '16', 'anos??'],
#  ['virando', 'o', 'padeiro', 'fofoqueiro', 'do', 'bairro'],
#  ['o', 'padeiro', 'fofoqueiro', 'do', 'bairro', 'tava'],
#  ['padeiro', 'fofoqueiro', 'do', 'bairro', 'tava', 'no'],
#  ['fofoqueiro', 'do', 'bairro', 'tava', 'no', 'portaozinho'],
#  ['do', 'bairro', 'tava', 'no', 'portaozinho', 'hoje'],
#  ['bairro', 'tava', 'no', 'portaozinho', 'hoje', 'e'],
#  ['tava', 'no', 'portaozinho', 'hoje', 'e', 'o'],
#  ['no', 'portaozinho', 'hoje', 'e', 'o', 'cliente'],
#  ['portaozinho', 'hoje', 'e', 'o', 'cliente', 'veio'],
#  ['hoje', 'e', 'o', 'cliente', 'veio', 'falar'],
#  ['e', 'o', 'cliente', 'veio', 'falar', 'do'],
#  ['o', 'cliente', 'veio', 'falar', 'do', 'casamento'],
#  ['cliente', 'veio', 'falar', 'do', 'casamento', 'dele..'],
#  ['pronto', 'pro', 'campeonato', 'das', 'loucas', 'empilhadas'],
#  ['dei', 'meucu', 'pra', 'pagar', 'esta', 'merda'],
#  ['meucu', 'pra', 'pagar', 'esta', 'merda', 'de'],
#  ['pra', 'pagar', 'esta', 'merda', 'de', 'cartao'],
#  ['pagar', 'esta', 'merda', 'de', 'cartao', 'e'],
#  ['esta', 'merda', 'de', 'cartao', 'e', 'ele'],
#  ['merda', 'de', 'cartao', 'e', 'ele', 'pediu'],
#  ['de', 'cartao', 'e', 'ele', 'pediu', 'MAIS'],
#  ['impossível', 'digerir', 'a', 'cpi', 'hoje', '😥'],
#  ['pensei', 'em', 'flertar', 'mas', 'só', 'curti'],
#  ['em', 'flertar', 'mas', 'só', 'curti', '🙏🏼🙏🏼'],
#  ['hum', 'que', 'delicia', 'o', 'almoço', 'do'],
#  ['que', 'delicia', 'o', 'almoço', 'do', 'fogão'],
#  ['delicia', 'o', 'almoço', 'do', 'fogão', 'vomitou'],
#  ['o', 'almoço', 'do', 'fogão', 'vomitou', 'e'],
#  ['almoço', 'do', 'fogão', 'vomitou', 'e', 'comeu'],
#  ['do', 'fogão', 'vomitou', 'e', 'comeu', 'o'],
#  ['fogão', 'vomitou', 'e', 'comeu', 'o', 'proprio'],
#  ['vomitou', 'e', 'comeu', 'o', 'proprio', 'vomito'],
#  ['e', 'comeu', 'o', 'proprio', 'vomito', '🤤🤤'],
#  ['sou', 'absurdamente', 'CONTRA', 'os', 'meus', 'amigos'],
#  ['absurdamente', 'CONTRA', 'os', 'meus', 'amigos', 'se'],
#  ['CONTRA', 'os', 'meus', 'amigos', 'se', 'relacionarem'],
#  ['batendo', 'o', 'meu', 'ponto', 'da', 'noite'],
#  ['o', 'meu', 'ponto', 'da', 'noite', 'nas'],
#  ['meu', 'ponto', 'da', 'noite', 'nas', 'redes'],
#  ['ponto', 'da', 'noite', 'nas', 'redes', 'sociais'],
#  ['da', 'noite', 'nas', 'redes', 'sociais', 'q'],
#  ['noite', 'nas', 'redes', 'sociais', 'q', 'criaram'],
#  ['nas', 'redes', 'sociais', 'q', 'criaram', 'um'],
#  ['redes', 'sociais', 'q', 'criaram', 'um', 'vínculo'],
#  ['sociais', 'q', 'criaram', 'um', 'vínculo', 'empregatício'],
#  ['q', 'criaram', 'um', 'vínculo', 'empregatício', 'comigo'],
#  ['criaram', 'um', 'vínculo', 'empregatício', 'comigo', 'sem'],
#  ['um', 'vínculo', 'empregatício', 'comigo', 'sem', 'clt'],
#  ['vínculo', 'empregatício', 'comigo', 'sem', 'clt', 'e'],
#  ['empregatício', 'comigo', 'sem', 'clt', 'e', 'sem'],
#  ['comigo', 'sem', 'clt', 'e', 'sem', 'ao'],
#  ['sem', 'clt', 'e', 'sem', 'ao', 'menos'],
#  ['clt', 'e', 'sem', 'ao', 'menos', 'me'],
#  ['e', 'sem', 'ao', 'menos', 'me', 'a…'],
#  ['sempre', 'um', 'ser', 'em', 'Sociedade', 'né'],
#  ['um', 'ser', 'em', 'Sociedade', 'né', 'poroca'],
#  ['em', 'dois', 'dias', 'meu', 'pc', 'morreu'],
#  ['dois', 'dias', 'meu', 'pc', 'morreu', 'meu'],
#  ['dias', 'meu', 'pc', 'morreu', 'meu', 'ventilador'],
#  ['meu', 'pc', 'morreu', 'meu', 'ventilador', 'grita'],
#  ['pc', 'morreu', 'meu', 'ventilador', 'grita', 'comigo'],
#  ['morreu', 'meu', 'ventilador', 'grita', 'comigo', 'toda'],
#  ['meu', 'ventilador', 'grita', 'comigo', 'toda', 'noite'],
#  ['ventilador', 'grita', 'comigo', 'toda', 'noite', 'estou'],
#  ['grita', 'comigo', 'toda', 'noite', 'estou', 'vivendo'],
#  ['comigo', 'toda', 'noite', 'estou', 'vivendo', 'a'],
#  ['toda', 'noite', 'estou', 'vivendo', 'a', 'revolução'],
#  ['noite', 'estou', 'vivendo', 'a', 'revolução', 'das'],
#  ['estou', 'vivendo', 'a', 'revolução', 'das', 'maquinas'],
#  ['eu', 'gosto', 'da', 'cabide', 'mas', 'sou'],
#  ['gosto', 'da', 'cabide', 'mas', 'sou', 'fã'],
#  ['da', 'cabide', 'mas', 'sou', 'fã', 'mesmo'],
#  ['cabide', 'mas', 'sou', 'fã', 'mesmo', 'da'],
#  ['mas', 'sou', 'fã', 'mesmo', 'da', 'frestas'],
#  ['streamer', 'milionário', 'tb', 'vai', 'pra', 'guilhotina'],
#  ['milionário', 'tb', 'vai', 'pra', 'guilhotina', 'na'],
#  ['tb', 'vai', 'pra', 'guilhotina', 'na', 'revolução'],
#  ['ser', 'amigo', 'de', 'pao', 'de', 'varios'],
#  ['amigo', 'de', 'pao', 'de', 'varios', 'tias'],
#  ['de', 'pao', 'de', 'varios', 'tias', 'e'],
#  ['pao', 'de', 'varios', 'tias', 'e', 'tios'],
#  ['de', 'varios', 'tias', 'e', 'tios', 'no'],
#  ['varios', 'tias', 'e', 'tios', 'no', 'insta'],
#  ['tias', 'e', 'tios', 'no', 'insta', 'eh'],
#  ['e', 'tios', 'no', 'insta', 'eh', 'falar'],
#  ['tios', 'no', 'insta', 'eh', 'falar', 'qualquer'],
#  ['no', 'insta', 'eh', 'falar', 'qualquer', 'coisa'],
#  ['insta', 'eh', 'falar', 'qualquer', 'coisa', 'tipo'],
#  ['eh', 'falar', 'qualquer', 'coisa', 'tipo', 'Modelagem'],
#  ['falar', 'qualquer', 'coisa', 'tipo', 'Modelagem', 'De'],
#  ['qualquer', 'coisa', 'tipo', 'Modelagem', 'De', 'Pao'],
#  ['coisa', 'tipo', 'Modelagem', 'De', 'Pao', 'Bundinha'],
#  ['tipo', 'Modelagem', 'De', 'Pao', 'Bundinha', 'e'],
#  ['Modelagem', 'De', 'Pao', 'Bundinha', 'e', 'esse'],
#  ['De', 'Pao', 'Bundinha', 'e', 'esse', 'povo…'],
#  ['vou', 'comprar', 'com', 'um', 'amigo', 'agora'],
#  ['comprar', 'com', 'um', 'amigo', 'agora', 'quer'],
#  ['com', 'um', 'amigo', 'agora', 'quer', 'colar?'],
#  ['um', 'amigo', 'agora', 'quer', 'colar?', 'n'],
#  ['amigo', 'agora', 'quer', 'colar?', 'n', 'sei'],
#  ['agora', 'quer', 'colar?', 'n', 'sei', 'qual'],
#  ['quer', 'colar?', 'n', 'sei', 'qual', 'eh'],
#  ['colar?', 'n', 'sei', 'qual', 'eh', 'nao'],
#  ['n', 'sei', 'qual', 'eh', 'nao', 'mas'],
#  ['sei', 'qual', 'eh', 'nao', 'mas', 'eh'],
#  ['qual', 'eh', 'nao', 'mas', 'eh', 'caro'],
#  ['GERALDO', 'AZEVEDO', 'SUA', 'MUSICA', 'SABOR', 'COLORIDO'],
#  ['AZEVEDO', 'SUA', 'MUSICA', 'SABOR', 'COLORIDO', 'EH'],
#  ['SUA', 'MUSICA', 'SABOR', 'COLORIDO', 'EH', 'SOBRE'],
#  ['MUSICA', 'SABOR', 'COLORIDO', 'EH', 'SOBRE', 'SACANAGEM?'],
#  ['vivendo', 'a', 'minha', 'maioridade:', 'comprando', 'peças'],
#  ['a', 'minha', 'maioridade:', 'comprando', 'peças', 'para'],
#  ['minha', 'maioridade:', 'comprando', 'peças', 'para', 'skate'],
#  ['maioridade:', 'comprando', 'peças', 'para', 'skate', 'de'],
#  ['comprando', 'peças', 'para', 'skate', 'de', 'dedo'],
#  ['quer', 'passar', 'a', 'terceira', 'idade', 'comigo'],
#  ['passar', 'a', 'terceira', 'idade', 'comigo', 'catilanga'],
#  ['eh', 'um', 'absurdo', 'eu', 'não', 'aguento'],
#  ['um', 'absurdo', 'eu', 'não', 'aguento', 'mais'],
#  ['futuro:', 'skates', 'que', 'voam', 'robos', 'escravos'],
#  ['skates', 'que', 'voam', 'robos', 'escravos', 'nosso'],
#  ['que', 'voam', 'robos', 'escravos', 'nosso', 'futuro:'],
#  ['voam', 'robos', 'escravos', 'nosso', 'futuro:', 'tiktik'],
#  ['robos', 'escravos', 'nosso', 'futuro:', 'tiktik', 'da'],
#  ['escravos', 'nosso', 'futuro:', 'tiktik', 'da', 'moça'],
#  ['nosso', 'futuro:', 'tiktik', 'da', 'moça', 'robo'],
#  ['futuro:', 'tiktik', 'da', 'moça', 'robo', 'do'],
#  ['tiktik', 'da', 'moça', 'robo', 'do', 'google'],
#  ['da', 'moça', 'robo', 'do', 'google', 'falando'],
#  ['nao', 'da', 'pra', 'fazer', 'carinho', 'em'],
#  ['da', 'pra', 'fazer', 'carinho', 'em', 'couve..'],
#  ['nao', 'tenho', 'nada', 'com', 'isso', 'me'],
#  ['tenho', 'nada', 'com', 'isso', 'me', 'tirem'],
#  ['nada', 'com', 'isso', 'me', 'tirem', 'daqui..'],
#  ['abri', 'aqui', 'e', 'acho', 'q', 'fui'],
#  ['aqui', 'e', 'acho', 'q', 'fui', 'cancelado'],
#  ['o', 'cara', 'aqui', 'na', 'nataçao', 'q'],
#  ['cara', 'aqui', 'na', 'nataçao', 'q', 'o'],
#  ['aqui', 'na', 'nataçao', 'q', 'o', 'job'],
#  ['na', 'nataçao', 'q', 'o', 'job', 'dele'],
#  ['nataçao', 'q', 'o', 'job', 'dele', 'eh'],
#  ['q', 'o', 'job', 'dele', 'eh', 'bota'],
#  ['o', 'job', 'dele', 'eh', 'bota', 'as'],
#  ['job', 'dele', 'eh', 'bota', 'as', 'Maiores'],
#  ['dele', 'eh', 'bota', 'as', 'Maiores', 'dos'],
#  ['eh', 'bota', 'as', 'Maiores', 'dos', 'remix'],
#  ['bota', 'as', 'Maiores', 'dos', 'remix', 'de'],
#  ['as', 'Maiores', 'dos', 'remix', 'de', 'oasis'],
#  ['Maiores', 'dos', 'remix', 'de', 'oasis', 'pra'],
#  ['dos', 'remix', 'de', 'oasis', 'pra', 'tocar'],
#  ['eh', 'muito', 'romantico', 'ne', 'a', 'parada'],
#  ['muito', 'romantico', 'ne', 'a', 'parada', 'eh'],
#  ['romantico', 'ne', 'a', 'parada', 'eh', 'que'],
#  ['ne', 'a', 'parada', 'eh', 'que', 'nao'],
#  ['a', 'parada', 'eh', 'que', 'nao', 'eh'],
#  ['parada', 'eh', 'que', 'nao', 'eh', 'bom'],
#  ['eh', 'que', 'nao', 'eh', 'bom', 'Querer'],
#  ['que', 'nao', 'eh', 'bom', 'Querer', 'Sentir'],
#  ['nao', 'eh', 'bom', 'Querer', 'Sentir', 'mas'],
#  ['eh', 'bom', 'Querer', 'Sentir', 'mas', 'vc'],
#  ['bom', 'Querer', 'Sentir', 'mas', 'vc', 'cai'],
#  ['Querer', 'Sentir', 'mas', 'vc', 'cai', 'nisso'],
#  ['Sentir', 'mas', 'vc', 'cai', 'nisso', 'sem'],
#  ['mas', 'vc', 'cai', 'nisso', 'sem', 'querer'],
#  ['vc', 'cai', 'nisso', 'sem', 'querer', 'né'],
#  ['cai', 'nisso', 'sem', 'querer', 'né', 'aí'],
#  ['nisso', 'sem', 'querer', 'né', 'aí', 'ao'],
#  ['sem', 'querer', 'né', 'aí', 'ao', 'menos'],
#  ['querer', 'né', 'aí', 'ao', 'menos', 'curte'],
#  ['né', 'aí', 'ao', 'menos', 'curte', 'o'],
#  ['aí', 'ao', 'menos', 'curte', 'o', 'banzo'],
#  ['tem', 'tempo', 'e', 'parte', 'eh', 'drama'],
#  ['tempo', 'e', 'parte', 'eh', 'drama', 'mas'],
#  ['e', 'parte', 'eh', 'drama', 'mas', 'eh'],
#  ['parte', 'eh', 'drama', 'mas', 'eh', 'bom'],
#  ['eh', 'drama', 'mas', 'eh', 'bom', 'sentir'],
#  ['drama', 'mas', 'eh', 'bom', 'sentir', 'um'],
#  ['mas', 'eh', 'bom', 'sentir', 'um', 'toquinho'],
#  ['eh', 'bom', 'sentir', 'um', 'toquinho', 'de'],
#  ['bom', 'sentir', 'um', 'toquinho', 'de', 'emoção...'],
#  ['infelizmente', 'vivendo', 'e', 'sentindo', 'o', 'álbum'],
#  ['vivendo', 'e', 'sentindo', 'o', 'álbum', 'Certa'],
#  ['e', 'sentindo', 'o', 'álbum', 'Certa', 'Manha'],
#  ['sentindo', 'o', 'álbum', 'Certa', 'Manha', 'Acordei'],
#  ['o', 'álbum', 'Certa', 'Manha', 'Acordei', 'De'],
#  ['álbum', 'Certa', 'Manha', 'Acordei', 'De', 'Sonhos'],
#  ['Certa', 'Manha', 'Acordei', 'De', 'Sonhos', 'Intranquilos'],
#  ['o', 'homem', 'que', 'perdeu', 'o', 'cabelo'],
#  ['homem', 'que', 'perdeu', 'o', 'cabelo', 'é'],
#  ['que', 'perdeu', 'o', 'cabelo', 'é', 'capaz'],
#  ['perdeu', 'o', 'cabelo', 'é', 'capaz', 'de'],
#  ['o', 'cabelo', 'é', 'capaz', 'de', 'perder'],
#  ['cabelo', 'é', 'capaz', 'de', 'perder', 'qualquer'],
#  ['é', 'capaz', 'de', 'perder', 'qualquer', 'coisa'],
#  ['eu', 'gosto', 'eh', 'da', 'organização', 'thi..'],
#  ['no', 'inconsciente', 'alheio', 'sou', 'o', 'famoso'],
#  ['inconsciente', 'alheio', 'sou', 'o', 'famoso', 'Empata'],
#  ['alheio', 'sou', 'o', 'famoso', 'Empata', 'Suruba'],
#  ['o', 'papao', 'nao', 'gosts', 'de', 'gengibre..'],
#  ['pita', 'q', 'pariu', 'eu', 'ia', 'dormir'],
#  ['q', 'pariu', 'eu', 'ia', 'dormir', 'agora'],
#  ['hidratando', 'o', 'pezinho', 'antes', 'de', 'dormir'],
#  ['o', 'pezinho', 'antes', 'de', 'dormir', 'pro'],
#  ['pezinho', 'antes', 'de', 'dormir', 'pro', 'papao'],
#  ['antes', 'de', 'dormir', 'pro', 'papao', 'nao'],
#  ['de', 'dormir', 'pro', 'papao', 'nao', 'pegar'],
#  ['acabei', 'de', 'rir', 'muito', 'e', 'meus'],
#  ['de', 'rir', 'muito', 'e', 'meus', 'dedos'],
#  ['rir', 'muito', 'e', 'meus', 'dedos', 'só'],
#  ['muito', 'e', 'meus', 'dedos', 'só', 'conseguiram'],
#  ['e', 'meus', 'dedos', 'só', 'conseguiram', 'digitar'],
#  ['meus', 'dedos', 'só', 'conseguiram', 'digitar', 'o'],
#  ['dedos', 'só', 'conseguiram', 'digitar', 'o', 'kkkkkkk'],
#  ['só', 'conseguiram', 'digitar', 'o', 'kkkkkkk', 'em'],
#  ['conseguiram', 'digitar', 'o', 'kkkkkkk', 'em', 'que'],
#  ['digitar', 'o', 'kkkkkkk', 'em', 'que', 'canto'],
#  ['o', 'kkkkkkk', 'em', 'que', 'canto', 'da'],
#  ['kkkkkkk', 'em', 'que', 'canto', 'da', 'internet'],
#  ['em', 'que', 'canto', 'da', 'internet', 'q'],
#  ['que', 'canto', 'da', 'internet', 'q', 'perdi'],
#  ['canto', 'da', 'internet', 'q', 'perdi', 'a'],
#  ['da', 'internet', 'q', 'perdi', 'a', 'minha'],
#  ['internet', 'q', 'perdi', 'a', 'minha', 'web'],
#  ['q', 'perdi', 'a', 'minha', 'web', 'alma..'],
#  ['o', 'freixo', 'ganhou', 'todos', 'os', 'nerdola'],
#  ['freixo', 'ganhou', 'todos', 'os', 'nerdola', 'liberal'],
#  ['ganhou', 'todos', 'os', 'nerdola', 'liberal', 'numa'],
#  ['todos', 'os', 'nerdola', 'liberal', 'numa', 'ida'],
#  ['os', 'nerdola', 'liberal', 'numa', 'ida', 'rapidinha'],
#  ['nerdola', 'liberal', 'numa', 'ida', 'rapidinha', 'no'],
#  ['liberal', 'numa', 'ida', 'rapidinha', 'no', 'flow'],
#  ['sempre', 'q', 'vou', 'ao', 'la', 'kanna'],
#  ['q', 'vou', 'ao', 'la', 'kanna', 'os'],
#  ['vou', 'ao', 'la', 'kanna', 'os', 'caras'],
#  ['ao', 'la', 'kanna', 'os', 'caras', 'sao'],
#  ['la', 'kanna', 'os', 'caras', 'sao', 'tao'],
#  ['kanna', 'os', 'caras', 'sao', 'tao', 'fofos'],
#  ['os', 'caras', 'sao', 'tao', 'fofos', 'q'],
#  ['caras', 'sao', 'tao', 'fofos', 'q', 'acabo'],
#  ['sao', 'tao', 'fofos', 'q', 'acabo', 'comprando'],
#  ['tao', 'fofos', 'q', 'acabo', 'comprando', 'qualquer'],
#  ['fofos', 'q', 'acabo', 'comprando', 'qualquer', 'coisa'],
#  ['toma', 'no', 'cu', 'o', 'tio', 'joao'],
#  ['no', 'cu', 'o', 'tio', 'joao', 'ta'],
#  ['cu', 'o', 'tio', 'joao', 'ta', '8'],
#  ['o', 'tio', 'joao', 'ta', '8', 'conto'],
#  ['ai', 'toda', 'hora', 'da', 'um', 'problema'],
#  ['toda', 'hora', 'da', 'um', 'problema', 'novo'],
#  ['hora', 'da', 'um', 'problema', 'novo', 'e'],
#  ['da', 'um', 'problema', 'novo', 'e', 'parece'],
#  ['um', 'problema', 'novo', 'e', 'parece', 'q'],
#  ['problema', 'novo', 'e', 'parece', 'q', 'eh'],
#  ['novo', 'e', 'parece', 'q', 'eh', 'coisa'],
#  ['e', 'parece', 'q', 'eh', 'coisa', 'da'],
#  ['parece', 'q', 'eh', 'coisa', 'da', 'mobo...'],
#  ['q', 'eh', 'coisa', 'da', 'mobo...', 'mas'],
#  ['eh', 'coisa', 'da', 'mobo...', 'mas', 'ele'],
#  ['coisa', 'da', 'mobo...', 'mas', 'ele', 'nao'],
#  ['da', 'mobo...', 'mas', 'ele', 'nao', 'ligar'],
#  ['mobo...', 'mas', 'ele', 'nao', 'ligar', 'periferico'],
#  ['mas', 'ele', 'nao', 'ligar', 'periferico', 'nem'],
#  ['ele', 'nao', 'ligar', 'periferico', 'nem', 'nada'],
#  ['nao', 'ligar', 'periferico', 'nem', 'nada', 'seria'],
#  ['ligar', 'periferico', 'nem', 'nada', 'seria', 'ram'],
#  ['periferico', 'nem', 'nada', 'seria', 'ram', 'tb?'],
#  ['sim!!', 'tenho', 'tido', 'problema', 'c', 'memorias'],
#  ['tenho', 'tido', 'problema', 'c', 'memorias', 'e'],
#  ['tido', 'problema', 'c', 'memorias', 'e', 'ja'],
#  ['problema', 'c', 'memorias', 'e', 'ja', 'limpei'],
#  ['c', 'memorias', 'e', 'ja', 'limpei', '(as'],
#  ['memorias', 'e', 'ja', 'limpei', '(as', 'vezes'],
#  ['e', 'ja', 'limpei', '(as', 'vezes', 'uma'],
#  ['ja', 'limpei', '(as', 'vezes', 'uma', 'funfa,'],
#  ['limpei', '(as', 'vezes', 'uma', 'funfa,', 'dps'],
#  ['(as', 'vezes', 'uma', 'funfa,', 'dps', 'outra,'],
#  ['vezes', 'uma', 'funfa,', 'dps', 'outra,', 'ultimamente'],
#  ['uma', 'funfa,', 'dps', 'outra,', 'ultimamente', 'qlqr'],
#  ['funfa,', 'dps', 'outra,', 'ultimamente', 'qlqr', 'cois…'],
#  ['meu', 'pc', 'liga', 'mas', 'nao', 'da'],
#  ['pc', 'liga', 'mas', 'nao', 'da', 'video/periferico'],
#  ['liga', 'mas', 'nao', 'da', 'video/periferico', 'n'],
#  ['mas', 'nao', 'da', 'video/periferico', 'n', 'liga'],
#  ['nao', 'da', 'video/periferico', 'n', 'liga', 'ai'],
#  ['da', 'video/periferico', 'n', 'liga', 'ai', 'falaram'],
#  ['video/periferico', 'n', 'liga', 'ai', 'falaram', 'pra'],
#  ['n', 'liga', 'ai', 'falaram', 'pra', 'fazer'],
#  ['liga', 'ai', 'falaram', 'pra', 'fazer', 'isso'],
#  ['ai', 'falaram', 'pra', 'fazer', 'isso', 'deixar'],
#  ['falaram', 'pra', 'fazer', 'isso', 'deixar', 'uns'],
#  ['pra', 'fazer', 'isso', 'deixar', 'uns', '10min'],
#  ['show!!', 'preciso', 'passar', 'ele', 'da', 'posição'],
#  ['preciso', 'passar', 'ele', 'da', 'posição', 'normal'],
#  ['passar', 'ele', 'da', 'posição', 'normal', 'pra'],
#  ['ele', 'da', 'posição', 'normal', 'pra', 'posição'],
#  ['da', 'posição', 'normal', 'pra', 'posição', 'c_cmos'],
#  ['mande', 'aquela', 'mensagem', 'safada', 'q', 'vc'],
#  ['aquela', 'mensagem', 'safada', 'q', 'vc', 'sempre'],
#  ['mensagem', 'safada', 'q', 'vc', 'sempre', 'quis'],
#  ['safada', 'q', 'vc', 'sempre', 'quis', 'mandar'],
#  ['q', 'vc', 'sempre', 'quis', 'mandar', 'aproveita'],
#  ['vc', 'sempre', 'quis', 'mandar', 'aproveita', 'que'],
#  ['sempre', 'quis', 'mandar', 'aproveita', 'que', 'nao'],
#  ['quis', 'mandar', 'aproveita', 'que', 'nao', 'da'],
#  ['mandar', 'aproveita', 'que', 'nao', 'da', 'pra'],
#  ['aproveita', 'que', 'nao', 'da', 'pra', 'ver'],
#  ['que', 'nao', 'da', 'pra', 'ver', '🤮🤮🤮'],
#  ['onde', 'ficam', 'os', 'pinos', 'C_CMOS', 'da'],
#  ['ficam', 'os', 'pinos', 'C_CMOS', 'da', 'placa'],
#  ['os', 'pinos', 'C_CMOS', 'da', 'placa', 'mãe'],
#  ['pinos', 'C_CMOS', 'da', 'placa', 'mãe', 'e'],
#  ['C_CMOS', 'da', 'placa', 'mãe', 'e', 'oq'],
#  ['da', 'placa', 'mãe', 'e', 'oq', 'eh'],
#  ['placa', 'mãe', 'e', 'oq', 'eh', 'um'],
#  ['mãe', 'e', 'oq', 'eh', 'um', 'JUMPER'],
#  ['preciso', 'da', 'ajuda', 'de', 'um', 'Nerd'],
#  ['ikkkkkkkk', 'r*naldo', 'l*mos', 'de', 'sunguinha', 'na'],
#  ['r*naldo', 'l*mos', 'de', 'sunguinha', 'na', 'tv'],
#  ['l*mos', 'de', 'sunguinha', 'na', 'tv', 'pedindo'],
#  ['de', 'sunguinha', 'na', 'tv', 'pedindo', 'pra'],
#  ['sunguinha', 'na', 'tv', 'pedindo', 'pra', 'reeditarem'],
#  ['na', 'tv', 'pedindo', 'pra', 'reeditarem', 'o'],
#  ['tv', 'pedindo', 'pra', 'reeditarem', 'o', 'take'],
#  ['sempre', 'q', 'vejo', 'ronaldo', 'lemos', 'na'],
#  ['q', 'vejo', 'ronaldo', 'lemos', 'na', 'tv'],
#  ['vejo', 'ronaldo', 'lemos', 'na', 'tv', 'arrepio'],
#  ['ronaldo', 'lemos', 'na', 'tv', 'arrepio', 'de'],
#  ['lemos', 'na', 'tv', 'arrepio', 'de', 'trauma'],
#  ['na', 'tv', 'arrepio', 'de', 'trauma', 'do'],
#  ['tv', 'arrepio', 'de', 'trauma', 'do', 'canal'],
#  ['arrepio', 'de', 'trauma', 'do', 'canal', 'futura..'],
#  ['poxa', 'amigo', 'ia', 'matar', 'a', 'paõ...'],
#  ['eu', 'so', 'eu', 'e', 'boi', 'nao'],
#  ['so', 'eu', 'e', 'boi', 'nao', 'lambe'],
#  ['eu', 'e', 'boi', 'nao', 'lambe', 'se'],
#  ['e', 'boi', 'nao', 'lambe', 'se', 'morde'],
#  ['boi', 'nao', 'lambe', 'se', 'morde', 'eu'],
#  ['nao', 'lambe', 'se', 'morde', 'eu', 'corto'],
#  ['lambe', 'se', 'morde', 'eu', 'corto', 'a'],
#  ['se', 'morde', 'eu', 'corto', 'a', 'lingua'],
#  ['e', 'eu', 'la', 'quero', 'saber', 'o'],
#  ['eu', 'la', 'quero', 'saber', 'o', 'que'],
#  ['la', 'quero', 'saber', 'o', 'que', 'aconteceu'],
#  ['quero', 'saber', 'o', 'que', 'aconteceu', 'de'],
#  ['saber', 'o', 'que', 'aconteceu', 'de', 'fato'],
#  ['o', 'que', 'aconteceu', 'de', 'fato', 'quero'],
#  ['que', 'aconteceu', 'de', 'fato', 'quero', 'ser'],
#  ['aconteceu', 'de', 'fato', 'quero', 'ser', 'abastecido'],
#  ['de', 'fato', 'quero', 'ser', 'abastecido', 'com'],
#  ['fato', 'quero', 'ser', 'abastecido', 'com', '7'],
#  ['quero', 'ser', 'abastecido', 'com', '7', 'teorias'],
#  ['ser', 'abastecido', 'com', '7', 'teorias', 'da'],
#  ['abastecido', 'com', '7', 'teorias', 'da', 'conspiração'],
#  ['com', '7', 'teorias', 'da', 'conspiração', 'diferentes'],
#  ['7', 'teorias', 'da', 'conspiração', 'diferentes', '👍🏼👍🏼'],
#  ['nao', 'dou', 'mole', 'pra', 'gente', 'lowprofile'],
#  ['que', 'papinho', 'de', 'nerd', 'hein', 'cade'],
#  ['papinho', 'de', 'nerd', 'hein', 'cade', 'a'],
#  ['de', 'nerd', 'hein', 'cade', 'a', 'bebida'],
#  ['tu', 'voltou', 'pro', 'twitter', 'tipo', 'um'],
#  ['voltou', 'pro', 'twitter', 'tipo', 'um', 'soldado'],
#  ['pro', 'twitter', 'tipo', 'um', 'soldado', 'se'],
#  ['twitter', 'tipo', 'um', 'soldado', 'se', 'apegando'],
#  ['tipo', 'um', 'soldado', 'se', 'apegando', 'a'],
#  ['um', 'soldado', 'se', 'apegando', 'a', 'ultima'],
#  ['soldado', 'se', 'apegando', 'a', 'ultima', 'trincheira'],
#  ['se', 'apegando', 'a', 'ultima', 'trincheira', 'disponível'],
#  ['apegando', 'a', 'ultima', 'trincheira', 'disponível', 'na'],
#  ['a', 'ultima', 'trincheira', 'disponível', 'na', 'guerra'],
#  ['ultima', 'trincheira', 'disponível', 'na', 'guerra', 'da'],
#  ['trincheira', 'disponível', 'na', 'guerra', 'da', 'internet'],
#  ['ip', 'e', 'ping', 'ip', 'e', 'ping'],
#  ['e', 'ping', 'ip', 'e', 'ping', 'abriram'],
#  ['ping', 'ip', 'e', 'ping', 'abriram', 'o'],
#  ['ip', 'e', 'ping', 'abriram', 'o', 'speedtest'],
#  ['A', 'ACAD', 'NAO', 'CAIU', 'NAO', 'HEIN'],
#  ['ACAD', 'NAO', 'CAIU', 'NAO', 'HEIN', 'HOJE'],
#  ['NAO', 'CAIU', 'NAO', 'HEIN', 'HOJE', 'EH'],
#  ['CAIU', 'NAO', 'HEIN', 'HOJE', 'EH', 'DIA'],
#  ['NAO', 'HEIN', 'HOJE', 'EH', 'DIA', 'DE'],
#  ['HEIN', 'HOJE', 'EH', 'DIA', 'DE', 'BIRLRLRLRL'],
#  ['o', 'correios', 'caiu', 'tambem', 'ninguem', 'tem'],
#  ['correios', 'caiu', 'tambem', 'ninguem', 'tem', 'mais'],
#  ['caiu', 'tambem', 'ninguem', 'tem', 'mais', 'cep'],
#  ['tambem', 'ninguem', 'tem', 'mais', 'cep', 'nao'],
#  ['ninguem', 'tem', 'mais', 'cep', 'nao', 'ouviu'],
#  ['tem', 'mais', 'cep', 'nao', 'ouviu', 'a'],
#  ['mais', 'cep', 'nao', 'ouviu', 'a', 'ultima'],
#  ['irmã', 'nao', 'sou', 'nira', 'vc', 'esta'],
#  ['nao', 'sou', 'nira', 'vc', 'esta', 'pirando'],
#  ['sou', 'nira', 'vc', 'esta', 'pirando', 'no'],
#  ['nira', 'vc', 'esta', 'pirando', 'no', 'bug'],
#  ['vc', 'esta', 'pirando', 'no', 'bug', 'do'],
#  ['esta', 'pirando', 'no', 'bug', 'do', 'milenioooo'],
#  ['🥵🥵ja', 'abri', 'pra', 'limpar', 'notificação', 'do'],
#  ['abri', 'pra', 'limpar', 'notificação', 'do', 'insta'],
#  ['pra', 'limpar', 'notificação', 'do', 'insta', 'umas'],
#  ['limpar', 'notificação', 'do', 'insta', 'umas', '9x'],
#  ['notificação', 'do', 'insta', 'umas', '9x', 'quero'],
#  ['do', 'insta', 'umas', '9x', 'quero', 'me'],
#  ['insta', 'umas', '9x', 'quero', 'me', 'mata'],
#  ['cai', 'tudo', 'menos', 'a', 'tua', 'bermuda'],
#  ['tudo', 'menos', 'a', 'tua', 'bermuda', 'tactel'],
#  ['menos', 'a', 'tua', 'bermuda', 'tactel', 'da'],
#  ['a', 'tua', 'bermuda', 'tactel', 'da', 'cyclone'],
#  ['tua', 'bermuda', 'tactel', 'da', 'cyclone', '😉🤤'],
#  ['😳😳😳😳😳', 'não', 'trabalho', 'com', 'pães', 'senhora'],
#  ['não', 'trabalho', 'com', 'pães', 'senhora', 'desculpe...'],
#  ['botei', 'o', 'meu', 'fermento', 'num', 'creme'],
#  ['o', 'meu', 'fermento', 'num', 'creme', 'de'],
#  ['meu', 'fermento', 'num', 'creme', 'de', 'castanha'],
#  ['fermento', 'num', 'creme', 'de', 'castanha', 'e'],
#  ['num', 'creme', 'de', 'castanha', 'e', 'simplesmente'],
#  ['creme', 'de', 'castanha', 'e', 'simplesmente', 'esta'],
#  ['de', 'castanha', 'e', 'simplesmente', 'esta', 'CRESCENDO'],
#  ['castanha', 'e', 'simplesmente', 'esta', 'CRESCENDO', 'eu'],
#  ['e', 'simplesmente', 'esta', 'CRESCENDO', 'eu', 'posso'],
#  ['simplesmente', 'esta', 'CRESCENDO', 'eu', 'posso', 'fermentar'],
#  ['esta', 'CRESCENDO', 'eu', 'posso', 'fermentar', 'TUDO'],
#  ['CRESCENDO', 'eu', 'posso', 'fermentar', 'TUDO', 'venha'],
#  ['eu', 'posso', 'fermentar', 'TUDO', 'venha', 'aqui'],
#  ['posso', 'fermentar', 'TUDO', 'venha', 'aqui', 'que'],
#  ['fermentar', 'TUDO', 'venha', 'aqui', 'que', 'eu…'],
#  ['vc', 'eh', 'meu', 'noco', 'melbor', 'amigo...'],
#  ['nao', 'vai', 'rolar', 'pq', 'teu', 'pau'],
#  ['vai', 'rolar', 'pq', 'teu', 'pau', 'deixou'],
#  ['rolar', 'pq', 'teu', 'pau', 'deixou', 'a'],
#  ['pq', 'teu', 'pau', 'deixou', 'a', 'desejar..'],
#  ['meis', 'amigos', 'ja', 'nao', 'me', 'aguentam'],
#  ['amigos', 'ja', 'nao', 'me', 'aguentam', 'mais'],
#  ['ja', 'nao', 'me', 'aguentam', 'mais', '😢'],
#  ['era', 'alguma', 'música', 'que', 'falava', 'em'],
#  ['alguma', 'música', 'que', 'falava', 'em', 'pequenas'],
#  ['música', 'que', 'falava', 'em', 'pequenas', 'letras'],
#  ['que', 'falava', 'em', 'pequenas', 'letras', 'que'],
#  ['falava', 'em', 'pequenas', 'letras', 'que', 'o'],
#  ['em', 'pequenas', 'letras', 'que', 'o', 'bob'],
#  ['pequenas', 'letras', 'que', 'o', 'bob', 'era'],
#  ['letras', 'que', 'o', 'bob', 'era', 'gay'],
#  ['que', 'o', 'bob', 'era', 'gay', 'agora'],
#  ['o', 'bob', 'era', 'gay', 'agora', 'não'],
#  ['bob', 'era', 'gay', 'agora', 'não', 'lembro'],
#  ['era', 'gay', 'agora', 'não', 'lembro', 'quem'],
#  ['catila', 'toda', 'força', 'pra', 'mulher', 'intensa..'],
#  ['sim', 'numa', 'dessas', 'já', 'encontrei', 'o'],
#  ['numa', 'dessas', 'já', 'encontrei', 'o', 'amor'],
#  ['calma', 'amigo', 'mark', 'só', 'esbarrou', 'nos'],
#  ['amigo', 'mark', 'só', 'esbarrou', 'nos', 'fio'],
#  ['ACABOU', 'O', 'SOL', 'EH', 'O', 'FIM'],
#  ['me', 'falem', 'a', 'altura', 'se', 'conseguir'],
#  ['falem', 'a', 'altura', 'se', 'conseguir', 'ir'],
#  ['a', 'altura', 'se', 'conseguir', 'ir', 'eu'],
#  ['altura', 'se', 'conseguir', 'ir', 'eu', 'vo!!'],
#  ['cade', 'o', 'fluxo', 'de', 'migração', 'telemática'],
#  ['o', 'fluxo', 'de', 'migração', 'telemática', 'para'],
#  ['fluxo', 'de', 'migração', 'telemática', 'para', 'o'],
#  ['de', 'migração', 'telemática', 'para', 'o', 'telegram'],
#  ['tatua', 'na', 'praia', 'agora', 'tudo', 'tem'],
#  ['na', 'praia', 'agora', 'tudo', 'tem', 'q'],
#  ['praia', 'agora', 'tudo', 'tem', 'q', 'ser'],
#  ['agora', 'tudo', 'tem', 'q', 'ser', 'feito'],
#  ['tudo', 'tem', 'q', 'ser', 'feito', 'na'],
#  ['tem', 'q', 'ser', 'feito', 'na', 'praia!!!'],
#  ['pedra', 'bial', 'caiçara', 'obrigado', 'pelo', 'lembrete'],
#  ['bial', 'caiçara', 'obrigado', 'pelo', 'lembrete', '🤝'],
#  ['fujam', 'dos', 'respectivos', 'trabalhoa', 'e', 'vamos'],
#  ['dos', 'respectivos', 'trabalhoa', 'e', 'vamos', 'a'],
#  ['respectivos', 'trabalhoa', 'e', 'vamos', 'a', 'praia!!!'],
#  ['trabalhoa', 'e', 'vamos', 'a', 'praia!!!', 'f…'],
#  ['nossa', 'bateu', 'essa', 'ideia', 'agora', 'adorei'],
#  ['bateu', 'essa', 'ideia', 'agora', 'adorei', 'a'],
#  ['essa', 'ideia', 'agora', 'adorei', 'a', 'confirmação'],
#  ['festa', 'no', 'twitter', 'AGORA', 'todos', 'online'],
#  ['no', 'twitter', 'AGORA', 'todos', 'online', 'quem'],
#  ['twitter', 'AGORA', 'todos', 'online', 'quem', 'trazer'],
#  ['AGORA', 'todos', 'online', 'quem', 'trazer', 'as'],
#  ['todos', 'online', 'quem', 'trazer', 'as', 'birita'],
#  ['pocinhas', 'pular', 'cerca', '(lisa)', 'vou', 'sim'],
#  ['pular', 'cerca', '(lisa)', 'vou', 'sim', 'anjo'],
#  ['cerca', '(lisa)', 'vou', 'sim', 'anjo', 'quando'],
#  ['(lisa)', 'vou', 'sim', 'anjo', 'quando', 'parar'],
#  ['vou', 'sim', 'anjo', 'quando', 'parar', 'os'],
#  ['sim', 'anjo', 'quando', 'parar', 'os', 'trabalhos..'],
#  ['um', 'dia', 'andorinhas', 'outro', 'dia', '7quedas'],
#  ['meter', 'a', 'mao', 'em', 'de', 'vaca!!'],
#  ['estou', 'falando', 'com', 'a', 'embaixadora', 'de'],
#  ['falando', 'com', 'a', 'embaixadora', 'de', 'S.J.'],
#  ['fumar', 'maconha', 'na', 'trilha', 'da', '7'],
#  ['maconha', 'na', 'trilha', 'da', '7', 'quedas'],
#  ['gente', 'oq', 'nao', 'posso', 'deixar', 'de'],
#  ['oq', 'nao', 'posso', 'deixar', 'de', 'fazer'],
#  ['nao', 'posso', 'deixar', 'de', 'fazer', 'em'],
#  ['posso', 'deixar', 'de', 'fazer', 'em', 'Aldeia'],
#  ['deixar', 'de', 'fazer', 'em', 'Aldeia', 'Velha????'],
#  ['postei', 'uma', 'besteira', 'me', 'curtiu', 'quem??'],
#  ['uma', 'besteira', 'me', 'curtiu', 'quem??', 'um'],
#  ['besteira', 'me', 'curtiu', 'quem??', 'um', 'machamp'],
#  ['me', 'curtiu', 'quem??', 'um', 'machamp', 'e'],
#  ['curtiu', 'quem??', 'um', 'machamp', 'e', 'um'],
#  ['quem??', 'um', 'machamp', 'e', 'um', 'kirby'],
#  ['mei', 'irmao', 'comeu', 'meu', 'acaraje', 'e'],
#  ['irmao', 'comeu', 'meu', 'acaraje', 'e', 'eu'],
#  ['comeu', 'meu', 'acaraje', 'e', 'eu', 'wuero'],
#  ['meu', 'acaraje', 'e', 'eu', 'wuero', 'mata-lo😡😡😡'],
#  ['eh', 'um', 'abuso', 'ANUNCIAR', 'a', 'fofoca'],
#  ['um', 'abuso', 'ANUNCIAR', 'a', 'fofoca', 'sem'],
#  ['abuso', 'ANUNCIAR', 'a', 'fofoca', 'sem', 'intenção'],
#  ['ANUNCIAR', 'a', 'fofoca', 'sem', 'intenção', 'de'],
#  ['a', 'fofoca', 'sem', 'intenção', 'de', 'EXPLANAR'],
#  ['eu', 'a', 'chamo', 'de', 'tesão', 'encroado'],
#  ['vo', 'te', 'aplica', 'um', 'café', 'pequeno'],
#  ['essa', 'galera', 'toda', 'eh', 'simplesmente', 'um'],
#  ['galera', 'toda', 'eh', 'simplesmente', 'um', 'moleque'],
#  ['toda', 'eh', 'simplesmente', 'um', 'moleque', 'do'],
#  ['eh', 'simplesmente', 'um', 'moleque', 'do', 'forum'],
#  ['simplesmente', 'um', 'moleque', 'do', 'forum', 'uol'],
#  ['um', 'moleque', 'do', 'forum', 'uol', 'jogos'],
#  ['kkekekekkee', 'os', 'queimadores', 'de', 'rosca', '😜😜😜'],
#  ['simm', 'essa', 'OBRA', 'eh', 'uma', 'crítica'],
#  ['essa', 'OBRA', 'eh', 'uma', 'crítica', 'ele'],
#  ['OBRA', 'eh', 'uma', 'crítica', 'ele', 'se'],
#  ['eh', 'uma', 'crítica', 'ele', 'se', 'ridiculariza'],
#  ['uma', 'crítica', 'ele', 'se', 'ridiculariza', 'cria'],
#  ['crítica', 'ele', 'se', 'ridiculariza', 'cria', 'um'],
#  ['ele', 'se', 'ridiculariza', 'cria', 'um', 'espantalho'],
#  ['se', 'ridiculariza', 'cria', 'um', 'espantalho', 'pra'],
#  ['ridiculariza', 'cria', 'um', 'espantalho', 'pra', 'criticar'],
#  ['cria', 'um', 'espantalho', 'pra', 'criticar', 'uma'],
#  ['um', 'espantalho', 'pra', 'criticar', 'uma', 'classe!!'],
#  ['ta', 'beijando', 'gente', 'q', 'gosta', 'de'],
#  ['beijando', 'gente', 'q', 'gosta', 'de', 'pdeira'],
#  ['gente', 'q', 'gosta', 'de', 'pdeira', 'ne'],
#  ['q', 'gosta', 'de', 'pdeira', 'ne', 'safada!!'],
#  ['por', 'fabor', 'computador', 'vc', 'poderia', 'ligar'],
#  ['fabor', 'computador', 'vc', 'poderia', 'ligar', 'marquei'],
#  ['computador', 'vc', 'poderia', 'ligar', 'marquei', 'rpg'],
#  ['vale', 'tudo', 'no', 'jogo', 'da', 'seducao'],
#  ['tudo', 'no', 'jogo', 'da', 'seducao', '!!'],
#  ['ja', 'parei', 'meu', 'limite', 'eh', 'enfia'],
#  ['parei', 'meu', 'limite', 'eh', 'enfia', 'o'],
#  ['meu', 'limite', 'eh', 'enfia', 'o', 'dedao'],
#  ['se', 'for', 'gostosinho', 'as', 'vezes', 'ate'],
#  ['for', 'gostosinho', 'as', 'vezes', 'ate', 'rola..'],
#  ['acha', 'um', 'saco', 'de', 'papel', 'bota'],
#  ['um', 'saco', 'de', 'papel', 'bota', 'uma'],
#  ['saco', 'de', 'papel', 'bota', 'uma', 'banana'],
#  ['de', 'papel', 'bota', 'uma', 'banana', 'e'],
#  ['papel', 'bota', 'uma', 'banana', 'e', 'ele'],
#  ['bota', 'uma', 'banana', 'e', 'ele', 'deixa'],
#  ['uma', 'banana', 'e', 'ele', 'deixa', 'namorar..'],
#  ['pe', 'pra', 'fora', '=', 'pedir', 'pra'],
#  ['pra', 'fora', '=', 'pedir', 'pra', 'ser'],
#  ['fora', '=', 'pedir', 'pra', 'ser', 'puxado'],
#  ['=', 'pedir', 'pra', 'ser', 'puxado', 'pelo'],
#  ['pedir', 'pra', 'ser', 'puxado', 'pelo', 'craminhao'],
#  ['espero', 'q', 'continue', 'assim', 'tomo', 'uma'],
#  ['q', 'continue', 'assim', 'tomo', 'uma', 'cerveja'],
#  ['continue', 'assim', 'tomo', 'uma', 'cerveja', 'e'],
#  ['assim', 'tomo', 'uma', 'cerveja', 'e', 'me'],
#  ['tomo', 'uma', 'cerveja', 'e', 'me', 'acabo..'],
#  ['hoje', 'simplssmenyr', 'perdi', 'o', 'conyrole', 'ds'],
#  ['simplssmenyr', 'perdi', 'o', 'conyrole', 'ds', 'minha.'],
#  ['perdi', 'o', 'conyrole', 'ds', 'minha.', 'vida'],
#  ['virei', 'o', 'cabofriense', 'de', 'sunga', 'boné'],
#  ['o', 'cabofriense', 'de', 'sunga', 'boné', 'e'],
#  ['cabofriense', 'de', 'sunga', 'boné', 'e', 'bike'],
#  ['se', 'vendessem', 'krokodil', 'em', 'vez', 'de'],
#  ['vendessem', 'krokodil', 'em', 'vez', 'de', 'alcool'],
#  ['krokodil', 'em', 'vez', 'de', 'alcool', 'falariam'],
#  ['em', 'vez', 'de', 'alcool', 'falariam', 'Que'],
#  ['vez', 'de', 'alcool', 'falariam', 'Que', 'Absurda'],
#  ['de', 'alcool', 'falariam', 'Que', 'Absurda', 'O'],
#  ['alcool', 'falariam', 'Que', 'Absurda', 'O', 'Uso'],
#  ['falariam', 'Que', 'Absurda', 'O', 'Uso', 'Da'],
#  ['Que', 'Absurda', 'O', 'Uso', 'Da', 'Droga'],
#  ['Absurda', 'O', 'Uso', 'Da', 'Droga', 'Que'],
#  ['O', 'Uso', 'Da', 'Droga', 'Que', 'Acaba'],
#  ['Uso', 'Da', 'Droga', 'Que', 'Acaba', 'Com'],
#  ['Da', 'Droga', 'Que', 'Acaba', 'Com', 'Vidas'],
#  ['pra', 'fechar', 'esse', 'dia', 'so', 'falta'],
#  ['fechar', 'esse', 'dia', 'so', 'falta', 'a'],
#  ['esse', 'dia', 'so', 'falta', 'a', 'icarly'],
#  ['dia', 'so', 'falta', 'a', 'icarly', 'universitaria'],
#  ['que', 'continuar', 'streamando', 'tenho', 'mais', 'oq'],
#  ['continuar', 'streamando', 'tenho', 'mais', 'oq', 'fazer'],
#  ['streamando', 'tenho', 'mais', 'oq', 'fazer', 'filhote'],
#  ['amo', 'pao', 'meu', 'deus', 'que', 'mundo'],
#  ['pao', 'meu', 'deus', 'que', 'mundo', 'lindo'],
#  ['ainda', 'bem', 'que', 'na', 'revolução', 'a'],
#  ['bem', 'que', 'na', 'revolução', 'a', 'primeira'],
#  ['que', 'na', 'revolução', 'a', 'primeira', 'fila'],
#  ['na', 'revolução', 'a', 'primeira', 'fila', 'de'],
#  ['revolução', 'a', 'primeira', 'fila', 'de', 'guilhotina'],
#  ['a', 'primeira', 'fila', 'de', 'guilhotina', 'vai'],
#  ['primeira', 'fila', 'de', 'guilhotina', 'vai', 'ser'],
#  ['fila', 'de', 'guilhotina', 'vai', 'ser', 'gente'],
#  ['de', 'guilhotina', 'vai', 'ser', 'gente', 'tipo'],
#  ['guilhotina', 'vai', 'ser', 'gente', 'tipo', 'otavio'],
#  ['vai', 'ser', 'gente', 'tipo', 'otavio', 'fakhoury'],
#  ['por', 'favor', 'quero', 'uma', 'unidade', 'de'],
#  ['favor', 'quero', 'uma', 'unidade', 'de', 'fim'],
#  ['quero', 'uma', 'unidade', 'de', 'fim', 'de'],
#  ['uma', 'unidade', 'de', 'fim', 'de', 'semana'],
#  ['meu', 'google', 'keep', 'atualmente', 'eh', 'so'],
#  ['google', 'keep', 'atualmente', 'eh', 'so', 'anotacao'],
#  ['keep', 'atualmente', 'eh', 'so', 'anotacao', 'de'],
#  ['atualmente', 'eh', 'so', 'anotacao', 'de', 'trabalho'],
#  ['eh', 'so', 'anotacao', 'de', 'trabalho', 'vida'],
#  ['so', 'anotacao', 'de', 'trabalho', 'vida', 'devolva'],
#  ['anotacao', 'de', 'trabalho', 'vida', 'devolva', 'a'],
#  ['de', 'trabalho', 'vida', 'devolva', 'a', 'minga'],
#  ['trabalho', 'vida', 'devolva', 'a', 'minga', 'fantasia'],
#  ['o', 'doido', 'de', 'voltar', 'a', 'morar'],
#  ['doido', 'de', 'voltar', 'a', 'morar', 'com'],
#  ['de', 'voltar', 'a', 'morar', 'com', 'a'],
#  ['voltar', 'a', 'morar', 'com', 'a', 'familia'],
#  ['a', 'morar', 'com', 'a', 'familia', 'em'],
#  ['morar', 'com', 'a', 'familia', 'em', 'cabofri'],
#  ['com', 'a', 'familia', 'em', 'cabofri', 'eh'],
#  ['a', 'familia', 'em', 'cabofri', 'eh', 'que'],
#  ['familia', 'em', 'cabofri', 'eh', 'que', 'eu'],
#  ['em', 'cabofri', 'eh', 'que', 'eu', 'tenho'],
#  ['cabofri', 'eh', 'que', 'eu', 'tenho', 'que'],
#  ['eh', 'que', 'eu', 'tenho', 'que', 'odiar'],
#  ['que', 'eu', 'tenho', 'que', 'odiar', 'os'],
#  ['eu', 'tenho', 'que', 'odiar', 'os', 'outros'],
#  ['tenho', 'que', 'odiar', 'os', 'outros', 'times'],
#  ['que', 'odiar', 'os', 'outros', 'times', 'agora'],
#  ['odiar', 'os', 'outros', 'times', 'agora', '!!'],
#  ['os', 'outros', 'times', 'agora', '!!', 'toma'],
#  ['outros', 'times', 'agora', '!!', 'toma', 'NO'],
#  ['times', 'agora', '!!', 'toma', 'NO', 'CU'],
#  ['agora', '!!', 'toma', 'NO', 'CU', 'MENGOO'],
#  ['tweet', 'de', 'amor', 'dedicado', 'a', 'pessoa'],
#  ['de', 'amor', 'dedicado', 'a', 'pessoa', 'q'],
#  ['amor', 'dedicado', 'a', 'pessoa', 'q', 'criou'],
#  ['dedicado', 'a', 'pessoa', 'q', 'criou', 'o'],
#  ['a', 'pessoa', 'q', 'criou', 'o', 'incensinho'],
#  ['pessoa', 'q', 'criou', 'o', 'incensinho', 'nag'],
#  ['q', 'criou', 'o', 'incensinho', 'nag', 'champa'],
#  ['thiago', 'eh', 'tao', 'preguiçoso', 'na', 'busca'],
#  ['eh', 'tao', 'preguiçoso', 'na', 'busca', 'da'],
#  ['tao', 'preguiçoso', 'na', 'busca', 'da', 'ENDORFINA'],
#  ['preguiçoso', 'na', 'busca', 'da', 'ENDORFINA', 'que'],
#  ['na', 'busca', 'da', 'ENDORFINA', 'que', 'mandou'],
#  ['busca', 'da', 'ENDORFINA', 'que', 'mandou', 'são'],
#  ['da', 'ENDORFINA', 'que', 'mandou', 'são', 'pedro'],
#  ['ENDORFINA', 'que', 'mandou', 'são', 'pedro', 'faze'],
#  ['que', 'mandou', 'são', 'pedro', 'faze', 'chuvê'],
#  ['cpi', 'no', 'maior', 'estilo', 'decada', 'de'],
#  ['no', 'maior', 'estilo', 'decada', 'de', '90'],
#  ['muito', 'dificil', 'começar', 'o', 'dia', 'com'],
#  ['dificil', 'começar', 'o', 'dia', 'com', 'esse'],
#  ['começar', 'o', 'dia', 'com', 'esse', 'video'],
#  ['o', 'dia', 'com', 'esse', 'video', 'e'],
#  ['dia', 'com', 'esse', 'video', 'e', 'esse'],
#  ['com', 'esse', 'video', 'e', 'esse', 'discurso'],
#  ['sem', 'tempo', 'pra', 'normalizar', 'a', 'romantização'],
#  ['tempo', 'pra', 'normalizar', 'a', 'romantização', 'hoje'],
#  ['ai', 'ai', 'ui', 'ui', 'nesse', 'pique'],
#  ['ai', 'ui', 'ui', 'nesse', 'pique', 'aqui'],
#  ['eu', 'pego', 'duas', 'vc', 'duas', 'fecho'],
#  ['porra', 'o', 'algoritmo', 'cismou', 'que', 'eu'],
#  ['o', 'algoritmo', 'cismou', 'que', 'eu', 'quero'],
#  ['algoritmo', 'cismou', 'que', 'eu', 'quero', '4'],
#  ['cismou', 'que', 'eu', 'quero', '4', 'shorts'],
#  ['que', 'eu', 'quero', '4', 'shorts', '100'],
#  ['eu', 'quero', '4', 'shorts', '100', 'reais'],
#  ['quero', '4', 'shorts', '100', 'reais', 'caralho'],
#  ['4', 'shorts', '100', 'reais', 'caralho', 'porra'],
#  ['shorts', '100', 'reais', 'caralho', 'porra', 'de'],
#  ['100', 'reais', 'caralho', 'porra', 'de', '4'],
#  ['reais', 'caralho', 'porra', 'de', '4', 'shorts'],
#  ['essa', 'e', 'pra', 'quem', 'e', 'preconceituoso'],
#  ['e', 'pra', 'quem', 'e', 'preconceituoso', 'e'],
#  ['pra', 'quem', 'e', 'preconceituoso', 'e', 'acha'],
#  ['quem', 'e', 'preconceituoso', 'e', 'acha', 'que'],
#  ['e', 'preconceituoso', 'e', 'acha', 'que', 'branco'],
#  ['preconceituoso', 'e', 'acha', 'que', 'branco', 'nao'],
#  ['e', 'acha', 'que', 'branco', 'nao', 'pode'],
#  ['acha', 'que', 'branco', 'nao', 'pode', 'tocar'],
#  ['que', 'branco', 'nao', 'pode', 'tocar', 'samba'],
#  ['bigode', 'é', 'a', 'franja', 'da', 'mulher??'],
#  ['acho', 'q', 'nao', 'to', 'bem', 'ha'],
#  ['q', 'nao', 'to', 'bem', 'ha', 'mt..'],
#  ['tao', 'louco', 'q', 'empurraria', 'um', 'carro'],
#  ['louco', 'q', 'empurraria', 'um', 'carro', 'na'],
#  ['q', 'empurraria', 'um', 'carro', 'na', 'lapa?'],
#  ['q', 'da', 'mole', 'pra', 'aluna', 'de'],
#  ['da', 'mole', 'pra', 'aluna', 'de', '15'],
#  ['saindo', 'voado', 'da', 'natação', 'pra', 'compensar'],
#  ['voado', 'da', 'natação', 'pra', 'compensar', 'a'],
#  ['da', 'natação', 'pra', 'compensar', 'a', 'abertura'],
#  ['natação', 'pra', 'compensar', 'a', 'abertura', 'do'],
#  ['pra', 'compensar', 'a', 'abertura', 'do', 'meu'],
#  ['compensar', 'a', 'abertura', 'do', 'meu', 'pulmão'],
#  ['a', 'abertura', 'do', 'meu', 'pulmão', 'fumando'],
#  ['abertura', 'do', 'meu', 'pulmão', 'fumando', 'o'],
#  ['do', 'meu', 'pulmão', 'fumando', 'o', 'famoso'],
#  ['meu', 'pulmão', 'fumando', 'o', 'famoso', 'pretinho'],
#  ['pulmão', 'fumando', 'o', 'famoso', 'pretinho', 'uva'],
#  ['imaginando', 'o', 'tal', 'ANCAPISTÃO', 'cheio', 'de'],
#  ['o', 'tal', 'ANCAPISTÃO', 'cheio', 'de', 'Prevent'],
#  ['tal', 'ANCAPISTÃO', 'cheio', 'de', 'Prevent', 'Senior'],
#  ['ANCAPISTÃO', 'cheio', 'de', 'Prevent', 'Senior', 'da'],
#  ['cheio', 'de', 'Prevent', 'Senior', 'da', 'vida'],
#  ['de', 'Prevent', 'Senior', 'da', 'vida', 'cuidando'],
#  ['Prevent', 'Senior', 'da', 'vida', 'cuidando', 'da'],
#  ['Senior', 'da', 'vida', 'cuidando', 'da', 'saúde'],
#  ['da', 'vida', 'cuidando', 'da', 'saúde', 'da'],
#  ['vida', 'cuidando', 'da', 'saúde', 'da', 'população'],
#  ['vendendo', 'pao', 'pra', 'burguesia', 'cabofriense', 'terça'],
#  ['pao', 'pra', 'burguesia', 'cabofriense', 'terça', 'feira:'],
#  ['pra', 'burguesia', 'cabofriense', 'terça', 'feira:', 'um'],
#  ['burguesia', 'cabofriense', 'terça', 'feira:', 'um', 'alemão'],
#  ['cabofriense', 'terça', 'feira:', 'um', 'alemão', 'veio'],
#  ['terça', 'feira:', 'um', 'alemão', 'veio', 'comprar'],
#  ['feira:', 'um', 'alemão', 'veio', 'comprar', 'pão'],
#  ['um', 'alemão', 'veio', 'comprar', 'pão', 'pois'],
#  ['alemão', 'veio', 'comprar', 'pão', 'pois', 'a'],
#  ['veio', 'comprar', 'pão', 'pois', 'a', 'Empregada'],
#  ['comprar', 'pão', 'pois', 'a', 'Empregada', 'dele'],
#  ['pão', 'pois', 'a', 'Empregada', 'dele', 'não'],
#  ['pois', 'a', 'Empregada', 'dele', 'não', 'sabe'],
#  ['a', 'Empregada', 'dele', 'não', 'sabe', 'fazer…'],
#  ['vc', 'sempre', 'esteve', 'a', 'frente', 'da'],
#  ['sempre', 'esteve', 'a', 'frente', 'da', 'geração'],
#  ['esteve', 'a', 'frente', 'da', 'geração', 'gio..'],
#  ['SENADOR', 'VOCÊ', 'COMPROU', 'ESSE', 'DIPLOMA??', 'MUITO'],
#  ['VOCÊ', 'COMPROU', 'ESSE', 'DIPLOMA??', 'MUITO', 'BURROOOOOO'],
#  ['o', 'lobby', 'da', 'paõ', 'é', 'tão'],
#  ['lobby', 'da', 'paõ', 'é', 'tão', 'forte'],
#  ['da', 'paõ', 'é', 'tão', 'forte', 'que'],
#  ['paõ', 'é', 'tão', 'forte', 'que', 'assusta'],
#  ['é', 'tão', 'forte', 'que', 'assusta', 'até'],
#  ['tão', 'forte', 'que', 'assusta', 'até', 'os'],
#  ['forte', 'que', 'assusta', 'até', 'os', 'psicólogos'],
#  ['que', 'assusta', 'até', 'os', 'psicólogos', 'mais'],
#  ['assusta', 'até', 'os', 'psicólogos', 'mais', 'Jungianos'],
#  ['reiterando', 'o', 'otavio', 'fakhoury', 'NAO', 'eh'],
#  ['o', 'otavio', 'fakhoury', 'NAO', 'eh', 'o'],
#  ['otavio', 'fakhoury', 'NAO', 'eh', 'o', 'meu'],
#  ['fakhoury', 'NAO', 'eh', 'o', 'meu', 'pai!!'],
#  ['alo', 'nova', 'geração', 'eh', 'feio', 'dividir'],
#  ['nova', 'geração', 'eh', 'feio', 'dividir', 'o'],
#  ['geração', 'eh', 'feio', 'dividir', 'o', 'cabelinho??'],
#  ['esse', 'ja', 'deu', 'briga', 'aqui', 'em'],
#  ['ja', 'deu', 'briga', 'aqui', 'em', 'casa..'],
#  ['fecha', 'o', 'olho', 'faz', 'uma', 'planta'],
#  ['o', 'olho', 'faz', 'uma', 'planta', 'baixa'],
#  ['olho', 'faz', 'uma', 'planta', 'baixa', 'do'],
#  ['faz', 'uma', 'planta', 'baixa', 'do', 'quarto'],
#  ['uma', 'planta', 'baixa', 'do', 'quarto', 'na'],
#  ['planta', 'baixa', 'do', 'quarto', 'na', 'cabeça'],
#  ['baixa', 'do', 'quarto', 'na', 'cabeça', 'que'],
#  ...]

# %%
def to_vec(tokens, model):
    return [model.wv[token] for token in tokens]

# %%
tokens_sentence = np.array([np.array(to_vec(tokens, word2vecmodel)) for tokens in tokens_sentence])

# %%
tokens_sentence.shape
# Out:
# (10012, 6, 50)

# %%
X = tokens_sentence[:, :INPUT_TOKEN_SIZE]

# %%
y = tokens_sentence[:, INPUT_TOKEN_SIZE]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM

# %%
model = Sequential()
model.add(LSTM(64, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64))
model.add(Dropout(0.2))
model.add(Dense(64))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1]))

# %%
model.compile(loss='mse', optimizer='adam')

# %%
model.fit(X, y, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 313/313 [==============================] - 6s 7ms/step - loss: 0.0036
# Epoch 2/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0035
# Epoch 3/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0034
# Epoch 4/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0033
# Epoch 5/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0033
# Epoch 6/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0033
# Epoch 7/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0032
# Epoch 8/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0032
# Epoch 9/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0032
# Epoch 10/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0032
# Epoch 11/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0032
# Epoch 12/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0032
# Epoch 13/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0032
# Epoch 14/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0032
# Epoch 15/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0032
# Epoch 16/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0032
# Epoch 17/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0032
# Epoch 18/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0032
# Epoch 19/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0032
# Epoch 20/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0032
# Epoch 21/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0032
# Epoch 22/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0032
# Epoch 23/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0032
# Epoch 24/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0032
# Epoch 25/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0032
# Epoch 26/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0032
# Epoch 27/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0032
# Epoch 28/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0032
# Epoch 29/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0032
# Epoch 30/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0032
# Epoch 31/100
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0031
# Epoch 32/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 33/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0031
# Epoch 34/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 35/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 36/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 37/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 38/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 39/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 40/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 41/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 42/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 43/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 44/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 45/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.0031
# Epoch 46/100
# 313/313 [==============================] - 4s 13ms/step - loss: 0.0031
# Epoch 47/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.0031
# Epoch 48/100
# 313/313 [==============================] - 4s 14ms/step - loss: 0.0031
# Epoch 49/100
# 313/313 [==============================] - 4s 12ms/step - loss: 0.0031
# Epoch 50/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0031
# Epoch 51/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 52/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 53/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 54/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 55/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 56/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 57/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 58/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 59/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 60/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 61/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 62/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 63/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 64/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 65/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0031
# Epoch 66/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0031
# Epoch 67/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0031
# Epoch 68/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0030
# Epoch 69/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0030
# Epoch 70/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0030
# Epoch 71/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0030
# Epoch 72/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0030
# Epoch 73/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0030
# Epoch 74/100
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0030
# Epoch 75/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0030
# Epoch 76/100
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0030
# Epoch 77/100
# 189/313 [=================>............] - ETA: 1s - loss: 0.0030

# %%
X_ = np.array([X[3], X[45], X[880]])
y_ = np.array([y[3], y[45], y[880]])
pred = model.predict(X_)

# %%
pred.shape
# Out:
# (3, 50)

# %%
def vec_to_word(array):
    sentences = []
    for sentence in array:
        words = []
        for word in sentence:
            x = word2vecmodel.wv.most_similar(positive=[word], topn=1)
            words.append(x[0][0])
        sentences.append(words)
    return sentences

# %%
vec_to_word(X_)
# Out:
# [['a', 'sua', 'nao', 'ouvi', 'o'],
#  ['fogao', 'ta', 'quase', 'bom', 'so'],
#  ['amor', 'dedicado', 'a', 'pessoa', 'q']]

# %%
vec_to_word([pred])
# Out:
# [['de', 'de', 'de']]

# %%
vec_to_word([y_])
# Out:
# [['desfecho', 'nao', 'criou']]

# %%
def generate_tweet():
    sentence = X[np.random.randint(0, len(X))]
    for _ in range(10):
        print(vec_to_word([sentence]))
        pred = model.predict(np.array([sentence[-3:]]))
        x = word2vecmodel.wv.most_similar(positive=pred, topn=10)
        p = [i[1] for i in x]
        s = sum(p)
        p = [i/s for i in p]
        word = np.random.choice([i[0] for i in x], p=p)
#         word = x[0][0]
        pred = np.array([word2vecmodel.wv[word]])
        sentence = np.concatenate((sentence, np.array(pred)), axis=0)
    return vec_to_word([sentence])

# %%
generate_tweet()
# Out:
# [['um', 'cara', 'q', 'sempre', 'gostei']]
# [['um', 'cara', 'q', 'sempre', 'gostei', 'de']]
# [['um', 'cara', 'q', 'sempre', 'gostei', 'de', 'de']]
# [['um', 'cara', 'q', 'sempre', 'gostei', 'de', 'de', 'e']]
# [['um', 'cara', 'q', 'sempre', 'gostei', 'de', 'de', 'e', 'a']]
# [['um', 'cara', 'q', 'sempre', 'gostei', 'de', 'de', 'e', 'a', 'na']]
# [['um', 'cara', 'q', 'sempre', 'gostei', 'de', 'de', 'e', 'a', 'na', 'e']]
# [['um', 'cara', 'q', 'sempre', 'gostei', 'de', 'de', 'e', 'a', 'na', 'e', 'que']]
# [['um', 'cara', 'q', 'sempre', 'gostei', 'de', 'de', 'e', 'a', 'na', 'e', 'que', 'de']]
# [['um', 'cara', 'q', 'sempre', 'gostei', 'de', 'de', 'e', 'a', 'na', 'e', 'que', 'de', 'que']]
# [['um',
#   'cara',
#   'q',
#   'sempre',
#   'gostei',
#   'de',
#   'de',
#   'e',
#   'a',
#   'na',
#   'e',
#   'que',
#   'de',
#   'que',
#   'que']]
